# %% [markdown]
# # Desqueeze VDM optics for IR8

# %%
# lhcoptics is installed within pip

from lhcoptics import LHCOptics, LHC
from lhcoptics import LHCCircuits

import pprint

# %% [markdown]
# ## Load VdM optics at 50m beta*

# %%
print(f' ----- : VdM Optics 2025:')
print(f' === Processess ===')
pprint.pprint(LHC().y2025.vdm.beam_processes)
# pprint.pprint(LHC().y2025.vdm.desqueeze)
for k,v  in LHC().y2025.vdm.beam_processes.items():
    print(f' \t process: {k}')
    pprint.pprint(dict(LHC().y2025.vdm.beam_processes[k].optics), width=40, indent=4)
# Out:
#  ----- : VdM Optics 2025:
#  === Processess ===
# {'desqueeze': <Process desqueeze:'DESQUEEZE-6.8TeV-VdM-IP8_50m-2025_V1' 4 optics>,
#  'physics': <Process physics:'PHYSICS-6.8TeV-VdM-2025_V1' 4 optics>,
#  'qchange': <Process qchange:'QCHANGE-6.8TeV-VdM-2025_V1' 2 optics>,
#  'ramp': <Process ramp:'RAMP-DESQUEEZE-6.8TeV-19_2m-VdM-2025_V1' 24 optics>}
#  	 process: ramp
# {   0: 'operation/optics/R2025aRP_A11mC11mA10mL10m_PhaseKnob100ON.madx',
#     15: 'operation/optics/R2025aRP_A11mC11mA10mL10m_PhaseKnob100ON.madx',
#     30: 'operation/optics/R2025aRP_A11mC11mA10mL10m_PhaseKnob100ON.madx',
#     45: 'operation/optics/R2025aRP_A11mC11mA10mL10m_PhaseKnob100ON.madx',
#     60: 'operation/optics/R2025aRP_A11mC11mA10mL10m_PhaseKnob100ON.madx',
#     90: 'operation/optics/R2025aRP_A11mC11mA10mL10m_PhaseKnob100ON.madx',
#     120: 'operation/optics/R2025aRP_A11mC11mA10mL10m_PhaseKnob100ON.madx',
#     152: 'operation/optics/R2025aRP_A11mC11mA10mL10m_PhaseKnob100ON.madx',
#     200: 'operation/optics/R2025aRP_A11mC11mA10mL10m_PhaseKnob75ON.madx',
#     240: 'operation/optics/R2025aRP_A11mC11mA10mL10m_PhaseKnob50ON.madx',
#     290: 'operation/optics/R2025aRP_A11mC11mA10mL10m_PhaseKnob25ON.madx',
#     405: 'operation/optics/R2025hRP_A11_2C11_2mA11_2mL11_2m.madx',
#     440: 'operation/optics/R2025hRP_A12_6mC12_6mA12_6mL12_6m.madx',
#     475: 'operation/optics/R2025hRP_A14_2mC14_2mA14_2mL14_2m.madx',
#     510: 'operation/optics/R2025hRP_A16mC16mA16mL16m.madx',
#     545: 'operation/optics/R2025hRP_A17_8mC17_8mA17_8mL17_8m.madx',
#     580: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL19_8m.madx',
#     650: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx',
#     720: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx',
#     755: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx',
#     900: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx',
#     1000: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx',
#     1100: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx',
#     1275: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx'}
#  	 process: desqueeze
# {   0: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx',
#     42: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL34m.madx',
#     84: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL44m.madx',
#     111: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL50m.madx'}
#  	 process: qchange
# {   0: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx',
#     25: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx'}
#  	 process: physics
# {   0: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx',
#     80: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx',
#     120: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx',
#     160: 'operation/optics/R2025hRP_A19_2mC19_2mA19_2mL24m.madx'}

# %%
# --- test: get collision optics at desqueeze
regenerate = False
if regenerate:
    opt = LHC().y2025.vdm.desqueeze[-3]
    opt.to_json("./data/vdmopt_2025_34m.json")

opt=LHCOptics.from_json("./data/vdmopt_2025_34m.json",xsuite_model=LHC().y2025.get_xsuite_json())

opt.ir8.plot()
_tt = opt.twiss(1)
print(f' -- beta values at IP8: {_tt["betx", "ip8"]=:.6g} - {_tt["bety", "ip8"]=:.6g} ')
# Out:
# Loading line from dict:   0%|          | 0/28955 [00:00<?, ?it/s]
# Done loading line from dict.
#  -- beta values at IP8: _tt["betx", "ip8"]=34 - _tt["bety", "ip8"]=34

# %%
# opt50m.model.info('acbxh3.r8') # show definition
opt.ir8.knobs
# Out:
# {'on_x8h': <IPKnob 'on_x8h' = -200.0>,
#  'on_sep8h': <IPKnob 'on_sep8h' = 0.0>,
#  'on_x8v': <IPKnob 'on_x8v' = 0.0>,
#  'on_sep8v': <IPKnob 'on_sep8v' = -1.0>,
#  'on_o8': <IPKnob 'on_o8' = 0.0>,
#  'on_oh8': <IPKnob 'on_oh8' = 0.0>,
#  'on_xip8b2': <IPKnob 'on_xip8b2' = 0.0>,
#  'on_xip8b1': <IPKnob 'on_xip8b1' = 0.0>,
#  'on_a8': <IPKnob 'on_a8' = 0.0>,
#  'on_ov8': <IPKnob 'on_ov8' = 0.0>,
#  'on_yip8b1': <IPKnob 'on_yip8b1' = 0.0>,
#  'on_yip8b2': <IPKnob 'on_yip8b2' = 0.0>}

# %%
pprint.pprint(opt.ir8.knobs['on_x8h'].weights)
pprint.pprint(opt.ir8.knobs['on_sep8h'].weights)
# Out:
# {'acbch5.l8b1': 0.0,
#  'acbchs5.l8b1': -2.13067218829e-07,
#  'acbchs5.l8b2': 1.99941670268e-07,
#  'acbxh1.l8': 9.48799226055e-08,
#  'acbxh1.r8': -9.48799226055e-08,
#  'acbxh2.l8': 9.48799226055e-08,
#  'acbxh2.r8': -9.48799226055e-08,
#  'acbxh3.l8': 9.48799226055e-08,
#  'acbxh3.r8': -9.48799226055e-08,
#  'acbyh4.l8b2': 0.0,
#  'acbyh4.r8b1': 0.0,
#  'acbyh5.r8b2': 0.0,
#  'acbyhs4.l8b1': -9.18222840558e-08,
#  'acbyhs4.l8b2': 2.52721608422e-07,
#  'acbyhs4.r8b1': 2.65511408769e-07,
#  'acbyhs4.r8b2': -7.88907003903e-08,
#  'acbyhs5.r8b1': 2.03840678175e-07,
#  'acbyhs5.r8b2': -2.07106977154e-07}
# {'acbch5.l8b1': 0.0,
#  'acbchs5.l8b1': -2.37176726472e-06,
#  'acbchs5.l8b2': -1.88735031444e-05,
#  'acbxh1.l8': 7.57276900576e-06,
#  'acbxh1.r8': 7.57276900576e-06,
#  'acbxh2.l8': 7.57276900576e-06,
#  'acbxh2.r8': 7.57276900576e-06,
#  'acbxh3.l8': 7.57276900576e-06,
#  'acbxh3.r8': 7.57276900576e-06,
#  'acbyh4.l8b2': 0.0,
#  'acbyh4.r8b1': 0.0,
#  'acbyh5.r8b2': 0.0,
#  'acbyhs4.l8b1': 1.27328515364e-05,
#  'acbyhs4.l8b2': 8.99673639469e-07,
#  'acbyhs4.r8b1': 3.07619885976e-07,
#  'acbyhs4.r8b2': -1.28768008606e-05,
#  'acbyhs5.r8b1': 1.92415536697e-05,
#  'acbyhs5.r8b2': 2.30542105639e-06}

# %%
opt.ir8.plot(yl='x y')
# Out:
# [<xtrack.twissplot.TwissPlot object at 0x1243acfb0>,
#  <xtrack.twissplot.TwissPlot object at 0x1333a1eb0>]

# %% [markdown]
# ## Check strengths

# %%
opt.set_circuits("data/lhccircuits.json")
# Out:
# <LHCOptics 'vdm_desqueeze_42'>

# %%
if 0 :
    opt50m.model['on_x8h'] = -300
    opt50m.model['on_x8v'] = 0.0
    opt50m.model['on_sep8v'] = -1
    opt50m.model['on_sep8h'] = 0

    # --- print current value of the kicker with this knob settings:
    print(opt50m.model['acbyhs5.r8b1'])

# %%
def check_strengths_at_knob_value(aknob, circ, value):
    ''' Check strengths at value for the knob'''
    for k, w in aknob.weights.items():
        _klimits = circ.madname[k].get_klimits()
        _setting = w*value
        if min(_klimits) <= w*value <= max(_klimits) :
            print(f'\t {k:>15s} = {w*value/1.0e-6:12.3f} [urad] - {_klimits}')
        else:
            print(f'\t {k:>15s} = {w*value/1.0e-6:12.3f} [urad] - {_klimits} - out of bounds')

    return

# %%
on_x8h = opt.ir8.knobs['on_x8h']
on_x8h.weights
# Out:
# {'acbch5.l8b1': 0.0,
#  'acbchs5.l8b1': -2.13067218829e-07,
#  'acbchs5.l8b2': 1.99941670268e-07,
#  'acbxh1.l8': 9.48799226055e-08,
#  'acbxh1.r8': -9.48799226055e-08,
#  'acbxh2.l8': 9.48799226055e-08,
#  'acbxh2.r8': -9.48799226055e-08,
#  'acbxh3.l8': 9.48799226055e-08,
#  'acbxh3.r8': -9.48799226055e-08,
#  'acbyh4.l8b2': 0.0,
#  'acbyh4.r8b1': 0.0,
#  'acbyh5.r8b2': 0.0,
#  'acbyhs4.l8b1': -9.18222840558e-08,
#  'acbyhs4.l8b2': 2.52721608422e-07,
#  'acbyhs4.r8b1': 2.65511408769e-07,
#  'acbyhs4.r8b2': -7.88907003903e-08,
#  'acbyhs5.r8b1': 2.03840678175e-07,
#  'acbyhs5.r8b2': -2.07106977154e-07}

# %%
check_strengths_at_knob_value(on_x8h, opt.circuits, 200)
# Out:
# 	     acbch5.l8b1 =        0.000 [urad] - [-9.70080123e-05  9.70080123e-05]
# 	    acbchs5.l8b1 =      -42.613 [urad] - [-9.70080123e-05  9.70080123e-05]
# 	    acbchs5.l8b2 =       39.988 [urad] - [-9.70080123e-05  9.70080123e-05]
# 	       acbxh1.l8 =       18.976 [urad] - [-5.29021913e-05  5.29021913e-05]
# 	       acbxh1.r8 =      -18.976 [urad] - [-5.29021913e-05  5.29021913e-05]
# 	       acbxh2.l8 =       18.976 [urad] - [-5.80515185e-05  5.80515185e-05]
# 	       acbxh2.r8 =      -18.976 [urad] - [-5.29021913e-05  5.29021913e-05]
# 	       acbxh3.l8 =       18.976 [urad] - [-5.29021913e-05  5.29021913e-05]
# 	       acbxh3.r8 =      -18.976 [urad] - [-6.18574582e-05  6.18574582e-05]
# 	     acbyh4.l8b2 =        0.000 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	     acbyh4.r8b1 =        0.000 [urad] - [-5.55441905e-05  5.55441905e-05]
# 	     acbyh5.r8b2 =        0.000 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	    acbyhs4.l8b1 =      -18.364 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	    acbyhs4.l8b2 =       50.544 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	    acbyhs4.r8b1 =       53.102 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	    acbyhs4.r8b2 =      -15.778 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	    acbyhs5.r8b1 =       40.768 [urad] - [-5.55441905e-05  5.55441905e-05]
# 	    acbyhs5.r8b2 =      -41.421 [urad] - [-9.70837957e-05  9.70837957e-05]

# %%
# --- update optics from model
# opt50m.ir8.update()
# opt50m.ir8.strengths

# %% [markdown]
# ## Add new knob in LHCOptics
#
# - example constructed from Riccardo.
#
# - Update the existing knob `on_x8h` to allow reaching -300 urad maintaining `acbyhs5.r8b1`
#
# - the new knob uses `acbch6.r8b1`

# %%
type(on_x8h)
# Out:
# lhcoptics.knob.IPKnob

# %%
print(on_x8h.const)
print(on_x8h.value)
on_x8h.weights
# Out:
# ['acbxh1.l8', 'acbxh1.r8', 'acbxh2.l8', 'acbxh2.r8', 'acbxh3.l8', 'acbxh3.r8']
# -200.0
# {'acbch5.l8b1': 0.0,
#  'acbchs5.l8b1': -2.13067218829e-07,
#  'acbchs5.l8b2': 1.99941670268e-07,
#  'acbxh1.l8': 9.48799226055e-08,
#  'acbxh1.r8': -9.48799226055e-08,
#  'acbxh2.l8': 9.48799226055e-08,
#  'acbxh2.r8': -9.48799226055e-08,
#  'acbxh3.l8': 9.48799226055e-08,
#  'acbxh3.r8': -9.48799226055e-08,
#  'acbyh4.l8b2': 0.0,
#  'acbyh4.r8b1': 0.0,
#  'acbyh5.r8b2': 0.0,
#  'acbyhs4.l8b1': -9.18222840558e-08,
#  'acbyhs4.l8b2': 2.52721608422e-07,
#  'acbyhs4.r8b1': 2.65511408769e-07,
#  'acbyhs4.r8b2': -7.88907003903e-08,
#  'acbyhs5.r8b1': 2.03840678175e-07,
#  'acbyhs5.r8b2': -2.07106977154e-07}

# %%
print(f' --- acbyhs5.r8b1: @200 urad = {on_x8h.weights["acbyhs5.r8b1"]*200}')
print(f' --- acbyhs5.r8b1: @300 urad = {on_x8h.weights["acbyhs5.r8b1"]*300}')
# Out:
#  --- acbyhs5.r8b1: @200 urad = 4.0768135635e-05
#  --- acbyhs5.r8b1: @300 urad = 6.11522034525e-05

# %%
# --- maintain acbyhs5.r8b1 to the 200 urad settings and scale it to 300 urad

on_x8h.const.append("acbyhs5.r8b1") # remember to do it again or check
on_x8h.weights["acbyhs5.r8b1"]*=200/300
on_x8h.weights
# Out:
# {'acbch5.l8b1': 0.0,
#  'acbchs5.l8b1': -2.13067218829e-07,
#  'acbchs5.l8b2': 1.99941670268e-07,
#  'acbxh1.l8': 9.48799226055e-08,
#  'acbxh1.r8': -9.48799226055e-08,
#  'acbxh2.l8': 9.48799226055e-08,
#  'acbxh2.r8': -9.48799226055e-08,
#  'acbxh3.l8': 9.48799226055e-08,
#  'acbxh3.r8': -9.48799226055e-08,
#  'acbyh4.l8b2': 0.0,
#  'acbyh4.r8b1': 0.0,
#  'acbyh5.r8b2': 0.0,
#  'acbyhs4.l8b1': -9.18222840558e-08,
#  'acbyhs4.l8b2': 2.52721608422e-07,
#  'acbyhs4.r8b1': 2.65511408769e-07,
#  'acbyhs4.r8b2': -7.88907003903e-08,
#  'acbyhs5.r8b1': 1.3589378545e-07,
#  'acbyhs5.r8b2': -2.07106977154e-07}

# %%
print(f' --- acbyhs5.r8b1: @200 urad = {on_x8h.weights["acbyhs5.r8b1"]*200}')
print(f' --- acbyhs5.r8b1: @300 urad = {on_x8h.weights["acbyhs5.r8b1"]*300}')
# Out:
#  --- acbyhs5.r8b1: @200 urad = 2.717875709e-05
#  --- acbyhs5.r8b1: @300 urad = 4.0768135634999997e-05

# %%
on_x8h.weights["acbch6.r8b1"]=2.49675503913e-07
on_x8h.weights
# Out:
# {'acbch5.l8b1': 0.0,
#  'acbchs5.l8b1': -2.13067218829e-07,
#  'acbchs5.l8b2': 1.99941670268e-07,
#  'acbxh1.l8': 9.48799226055e-08,
#  'acbxh1.r8': -9.48799226055e-08,
#  'acbxh2.l8': 9.48799226055e-08,
#  'acbxh2.r8': -9.48799226055e-08,
#  'acbxh3.l8': 9.48799226055e-08,
#  'acbxh3.r8': -9.48799226055e-08,
#  'acbyh4.l8b2': 0.0,
#  'acbyh4.r8b1': 0.0,
#  'acbyh5.r8b2': 0.0,
#  'acbyhs4.l8b1': -9.18222840558e-08,
#  'acbyhs4.l8b2': 2.52721608422e-07,
#  'acbyhs4.r8b1': 2.65511408769e-07,
#  'acbyhs4.r8b2': -7.88907003903e-08,
#  'acbyhs5.r8b1': 1.3589378545e-07,
#  'acbyhs5.r8b2': -2.07106977154e-07,
#  'acbch6.r8b1': 2.49675503913e-07}

# %%
opt.update_model()
on_x8h.match()
opt.ir8.update_knobs()
# Out:
# Target status:               alty = 3.5513e-02
# id state tag       tol_met       residue   current_val    target_val description
# 0  ON    b1_ip8_x     True   3.91594e-10   3.91632e-10   3.78914e-14 line=b1, ('x', 'ip8'), val=3.78914e-14,  ...
# 1  ON    b2_ip8_x     True   3.36148e-11   3.38279e-11   2.13109e-13 line=b2, ('x', 'ip8'), val=2.13109e-13,  ...
# 2  ON    b1_ip8_px    True   3.53185e-11       0.00017       0.00017 line=b1, ('px', 'ip8'), val=0.00017, tol ...
# 3  ON    b2_ip8_px    True  -1.76133e-11      -0.00017      -0.00017 line=b2, ('px', 'ip8'), val=-0.00017, to ...
# 4  ON    b1_END_x    False   -0.00354701   -0.00354701  -2.31774e-12 line=b1, ('x', 'e.ds.r8.b1'), val=-2.317 ...
# 5  ON    b2_END_x     True   -8.8999e-10  -8.82668e-10   7.32225e-12 line=b2, ('x', 'e.ds.r8.b2'), val=7.3222 ...
# 6  ON    b1_END_px   False   -1.7529e-05   -1.7529e-05   4.72713e-14 line=b1, ('px', 'e.ds.r8.b1'), val=4.727 ...
# 7  ON    b2_END_px    True   4.69099e-12   4.61227e-12  -7.87214e-14 line=b2, ('px', 'e.ds.r8.b2'), val=-7.87 ...
# Matching: model call n. 37 penalty = 3.0775e-09
# <LHCIR8 in 'vdm_desqueeze_42'>

# %%
on_x8h.plot()
print(on_x8h.weights["acbyhs5.r8b1"]*300)
# Out:
# 4.0768135634999997e-05

# %%
check_strengths_at_knob_value(opt.ir8.knobs['on_x8h'], opt.circuits, 300)
# Out:
# 	     acbch5.l8b1 =        0.000 [urad] - [-9.70080123e-05  9.70080123e-05]
# 	    acbchs5.l8b1 =      -63.921 [urad] - [-9.70080123e-05  9.70080123e-05]
# 	    acbchs5.l8b2 =       59.983 [urad] - [-9.70080123e-05  9.70080123e-05]
# 	       acbxh1.l8 =       28.463 [urad] - [-5.29021913e-05  5.29021913e-05]
# 	       acbxh1.r8 =      -22.757 [urad] - [-5.29021913e-05  5.29021913e-05]
# 	       acbxh2.l8 =       28.465 [urad] - [-5.80515185e-05  5.80515185e-05]
# 	       acbxh2.r8 =       -8.548 [urad] - [-5.29021913e-05  5.29021913e-05]
# 	       acbxh3.l8 =       28.464 [urad] - [-5.29021913e-05  5.29021913e-05]
# 	       acbxh3.r8 =      -42.960 [urad] - [-6.18574582e-05  6.18574582e-05]
# 	     acbyh4.l8b2 =        0.000 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	     acbyh4.r8b1 =        0.000 [urad] - [-5.55441905e-05  5.55441905e-05]
# 	     acbyh5.r8b2 =        0.000 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	    acbyhs4.l8b1 =      -27.545 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	    acbyhs4.l8b2 =       75.816 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	    acbyhs4.r8b1 =       87.000 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	    acbyhs4.r8b2 =      -16.632 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	    acbyhs5.r8b1 =       29.973 [urad] - [-5.55441905e-05  5.55441905e-05]
# 	    acbyhs5.r8b2 =      -68.119 [urad] - [-9.70837957e-05  9.70837957e-05]
# 	     acbch6.r8b1 =       20.503 [urad] - [-9.70080123e-05  9.70080123e-05]

# %%
opt.to_madx(output="./data/vdmoptics_2025.9")

# %% [markdown]
# ## Add new knob in MAD-X
#
# To make this work, I had to do a symlink : acc-models-lhc --> ~/.local/acc-models-lhc/2025

# %%
! ls acc-models-lhc/scenarios/cycle/vdm/desqueeze/
# Out:
# 0           111         42          84          readme.yaml

# %%
! cat acc-models-lhc/2025/operation/optics/R2025hRP_A19_2mC19_2mA19_2mL50m.madx
# Out:
# cat: acc-models-lhc/2025/operation/optics/R2025hRP_A19_2mC19_2mA19_2mL50m.madx: No such file or directory

# %%
from cpymad.madx import Madx

mymad  = Madx()
mymad.options['echo'] = False
mymad.options['warn'] = False
mymad.options['info'] = False
# 111 = 50m, 84 = 44m, 42 = 34m 0 = 24m
mymad.call("acc-models-lhc/scenarios/cycle/vdm/desqueeze/42/model.madx")
mymad.use('lhcb1')
mymad.twiss()
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.09.03  (64 bit, Darwin)      +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2024.04.25               +
#   + Execution date: 2025.05.07 17:49:14      +
#   ++++++++++++++++++++++++++++++++++++++++++++
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000076924E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.517240639264600
#  Step length    1.0000002894742086
# call:     2 Dx =   0.10000003E+01  Penalty function =  0.2213740125899274E-18
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.517240410931016
#  Step length    3.3516109778406615E-008
# call:     3 Dx =   0.33516110E-07  Penalty function =  0.1387913597137809E-32
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.2665363123383797E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip1:1                      x            4     1.00000000E-03     1.00000000E-03     1.69271187E-34
# ip1:1                      px           4     0.00000000E+00     9.21587802E-21     8.49324077E-37
# s.ds.r1.b1:1               x            4     0.00000000E+00    -3.41370673E-18     1.16533937E-33
# s.ds.r1.b1:1               px           4     0.00000000E+00     7.24249405E-20     5.24537200E-35
#
#
# Final Penalty Function =   1.38791360e-33
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip1b1_acbch5.r1b1    -7.44869e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b1_acbyhs4.r1b1    1.34866e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b1_acbch6.l1b1    -2.96467e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b1_acbyh4.l1b1     3.34012e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.38791360e-33
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000077162E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    17.644947271671263
#  Step length   0.99999980971476343
# call:     2 Dx =   0.99999981E+00  Penalty function =  0.1026633670254901E-17
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    17.644946314972366
#  Step length    6.0634117850894120E-008
# call:     3 Dx =   0.60634118E-07  Penalty function =  0.1358913953024163E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.2049648522409070E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip1:1                      x            4     1.00000000E-03     1.00000000E-03     1.88079096E-35
# ip1:1                      px           4     0.00000000E+00    -2.50131439E-20     6.25657370E-36
# s.ds.r1.b2:1               x            4     0.00000000E+00     1.05161829E-18     1.10590102E-34
# s.ds.r1.b2:1               px           4     0.00000000E+00    -4.86631250E-21     2.36809974E-37
#
#
# Final Penalty Function =   1.35891395e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip1b2_acbyh4.r1b2     4.01147e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b2_acbch6.r1b2    -3.17901e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b2_acbyhs4.l1b2    1.18548e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b2_acbch5.l1b2    -6.63913e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.35891395e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999964465944447E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    17.259373942634671
#  Step length   0.99999943290506721
# call:     2 Dx =   0.99999943E+00  Penalty function =  0.1068419779395480E-14
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    17.259325739794658
#  Step length    3.2686651810078803E-006
# call:     3 Dx =   0.32686652E-05  Penalty function =  0.1069759568187360E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.2104957806211875E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip1:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip1:1                      py           4     0.00000000E+00    -5.98199250E-21     3.57842342E-37
# s.ds.r1.b1:1               y            4     0.00000000E+00     9.33589977E-19     8.71590244E-35
# s.ds.r1.b1:1               py           4     0.00000000E+00     3.84149875E-20     1.47571127E-35
#
#
# Final Penalty Function =   1.06975957e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip1b1_acbyvs4.l1b1    1.21762e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b1_acbcv5.l1b1    -6.62022e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b1_acbyv4.r1b1     3.56165e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b1_acbcv6.r1b1    -3.15259e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.06975957e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000078776E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    68.569041201396388
#  Step length    1.0000002958021508
# call:     2 Dx =   0.10000003E+01  Penalty function =  0.3673755598056369E-26
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    68.569041202705989
#  Step length    1.4807967154571601E-011
# call:     3 Dx =   0.14807967E-10  Penalty function =  0.1323569179942764E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.2617088396948689E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip1:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip1:1                      py           4     0.00000000E+00    -2.35072761E-20     5.52592030E-36
# s.ds.r1.b2:1               y            4     0.00000000E+00     1.09837677E-18     1.20643152E-34
# s.ds.r1.b2:1               py           4     0.00000000E+00    -1.21896199E-20     1.48586834E-36
#
#
# Final Penalty Function =   1.32356918e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip1b2_acbcv5.r1b2    -7.49614e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b2_acbyv4.l1b2     3.79015e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b2_acbcv6.l1b2    -3.00581e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b2_acbyvs4.r1b2    1.31843e-04  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.32356918e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000028551E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    54.092573162741509
#  Step length    1.0000003757806313
# call:     2 Dx =   0.10000004E+01  Penalty function =  0.3310329776652783E-17
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    54.092574338805051
#  Step length    7.1298681588706271E-008
# call:     3 Dx =   0.71298682E-07  Penalty function =  0.2239323981838080E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.2009723824283166E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip2:1                      x            4     1.00000000E-03     1.00000000E-03     1.88079096E-35
# ip2:1                      px           4     0.00000000E+00     3.35518625E-20     1.12572748E-35
# s.ds.r2.b1:1               x            4     0.00000000E+00     1.39142915E-18     1.93607508E-34
# s.ds.r2.b1:1               px           4     0.00000000E+00    -5.09612908E-21     2.59705316E-37
#
#
# Final Penalty Function =   2.23932398e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip2b1_acbchs5.r2b1   -7.81747e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b1_acbyhs4.l2b1    9.47017e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b1_acbyh5.l2b1    -4.23129e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b1_acbyh4.r2b1     6.27153e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   2.23932398e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999949617367454E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    78.008428748807816
#  Step length   0.99999976304108440
# call:     2 Dx =   0.99999976E+00  Penalty function =  0.2731080537102912E-16
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    78.008435755300937
#  Step length    4.6727465402543123E-007
# call:     3 Dx =   0.46727465E-06  Penalty function =  0.9930144275496321E-34
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.1483826483753181E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip2:1                      x            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip2:1                      px           4     0.00000000E+00     7.25471712E-21     5.26309204E-37
# s.ds.r2.b2:1               x            4     0.00000000E+00    -9.66127745E-19     9.33402820E-35
# s.ds.r2.b2:1               px           4     0.00000000E+00     8.56080673E-21     7.32874118E-37
#
#
# Final Penalty Function =   9.93014428e-35
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip2b2_acbyh4.l2b2     4.12117e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b2_acbch5.r2b2    -4.79097e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b2_acbyhs4.r2b2    1.04617e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b2_acbyhs5.l2b2   -4.95318e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   9.93014428e-35
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000164995E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    78.784560396640387
#  Step length    1.0000002779198049
# call:     2 Dx =   0.10000003E+01  Penalty function =  0.1232856975781770E-24
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    78.784560396228287
#  Step length    5.9146373227027405E-012
# call:     3 Dx =   0.59146373E-11  Penalty function =  0.1505585473337026E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.1462081394757960E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip2:1                      y            4     1.00000000E-03     1.00000000E-03     1.17549435E-34
# ip2:1                      py           4     0.00000000E+00    -4.84775533E-20     2.35007318E-35
# s.ds.r2.b1:1               y            4     0.00000000E+00    -2.75981996E-19     7.61660622E-36
# s.ds.r2.b1:1               py           4     0.00000000E+00    -1.37541785E-20     1.89177425E-36
#
#
# Final Penalty Function =   1.50558547e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip2b1_acbcv5.r2b1    -4.79703e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b1_acbyv4.l2b1     4.01622e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b1_acbyvs5.l2b1   -4.96566e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b1_acbyvs4.r2b1    1.04310e-04  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.50558547e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000032380E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.810009121637187
#  Step length    1.0000003790504097
# call:     2 Dx =   0.10000004E+01  Penalty function =  0.5767839823467374E-24
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.810009116237374
#  Step length    6.0869043809151890E-011
# call:     3 Dx =   0.60869044E-10  Penalty function =  0.2496097971148733E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.1987203539222942E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip2:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip2:1                      py           4     0.00000000E+00    -2.21636513E-20     4.91227437E-36
# s.ds.r2.b2:1               y            4     0.00000000E+00    -1.54435417E-18     2.38502981E-34
# s.ds.r2.b2:1               py           4     0.00000000E+00     1.22170566E-20     1.49256473E-36
#
#
# Final Penalty Function =   2.49609797e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip2b2_acbcvs5.r2b2   -7.82651e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b2_acbyv4.r2b2     6.21833e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b2_acbyv5.l2b2    -4.24268e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b2_acbyvs4.l2b2    9.41035e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   2.49609797e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999963404679191E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.545842095894059
#  Step length    1.0000000894166667
# call:     2 Dx =   0.10000001E+01  Penalty function =  0.1182630987840349E-15
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.545837252841878
#  Step length    1.0359415252519416E-006
# call:     3 Dx =   0.10359415E-05  Penalty function =  0.6422688089840390E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.3407936399166421E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip5:1                      x            4     1.00000000E-03     1.00000000E-03     1.88079096E-35
# ip5:1                      px           4     0.00000000E+00    -2.11748216E-20     4.48373070E-36
# s.ds.r5.b1:1               x            4     0.00000000E+00     2.38327343E-18     5.67999224E-34
# s.ds.r5.b1:1               px           4     0.00000000E+00    -7.13988409E-20     5.09779448E-35
#
#
# Final Penalty Function =   6.42268809e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip5b1_acbch6.l5b1    -2.88979e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b1_acbyhs4.r5b1    1.28218e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b1_acbyh4.l5b1     6.99607e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b1_acbch5.r5b1    -1.00741e-04  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   6.42268809e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000022028E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    21.789592276545797
#  Step length    1.0000000675672414
# call:     2 Dx =   0.10000001E+01  Penalty function =  0.1964563792990796E-17
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    21.789591414341842
#  Step length    2.5374696050969896E-008
# call:     3 Dx =   0.25374696E-07  Penalty function =  0.5818941596654206E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.4246058542161809E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip5:1                      x            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip5:1                      px           4     0.00000000E+00     4.42011535E-20     1.95374197E-35
# s.ds.r5.b2:1               x            4     0.00000000E+00     2.36141381E-18     5.57627519E-34
# s.ds.r5.b2:1               px           4     0.00000000E+00    -1.65057625E-21     2.72440194E-38
#
#
# Final Penalty Function =   5.81894160e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip5b2_acbch6.r5b2    -2.78301e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b2_acbyh4.r5b2     6.80301e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b2_acbch5.l5b2    -1.15589e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b2_acbyhs4.l5b2    1.49751e-04  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   5.81894160e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999966300695303E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    22.030165450302075
#  Step length   0.99999963627005894
# call:     2 Dx =   0.99999964E+00  Penalty function =  0.8157938043624313E-15
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    22.030227259440384
#  Step length    2.8561947748349392E-006
# call:     3 Dx =   0.28561948E-05  Penalty function =  0.1413152246774501E-34
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.4244504749533352E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip5:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip5:1                      py           4     0.00000000E+00    -1.01794865E-20     1.03621945E-36
# s.ds.r5.b1:1               y            4     0.00000000E+00     2.89571843E-19     8.38518525E-36
# s.ds.r5.b1:1               py           4     0.00000000E+00    -9.02239897E-22     8.14036832E-39
#
#
# Final Penalty Function =   1.41315225e-35
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip5b1_acbyvs4.l5b1    1.49750e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b1_acbcv6.r5b1    -2.79728e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b1_acbyv4.r5b1     6.78407e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b1_acbcv5.l5b1    -1.15589e-04  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.41315225e-35
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000086174E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    62.109222660573863
#  Step length   0.99999960378971209
# call:     2 Dx =   0.99999960E+00  Penalty function =  0.1323222070894019E-23
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    62.109222660526328
#  Step length    1.3468965494437679E-011
# call:     3 Dx =   0.13468965E-10  Penalty function =  0.3421445760078814E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.3411894791590573E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip5:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip5:1                      py           4     0.00000000E+00     2.51207178E-20     6.31050465E-36
# s.ds.r5.b2:1               y            4     0.00000000E+00    -1.81968263E-18     3.31124486E-34
# s.ds.r5.b2:1               py           4     0.00000000E+00    -8.72235820E-22     7.60795326E-39
#
#
# Final Penalty Function =   3.42144576e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip5b2_acbyvs4.r5b2    1.28200e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b2_acbcv5.r5b2    -1.00887e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b2_acbcv6.l5b2    -2.87307e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b2_acbyv4.l5b2     7.01254e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   3.42144576e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999947115297058E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    21.222175823602395
#  Step length   0.99999910740895437
# call:     2 Dx =   0.99999911E+00  Penalty function =  0.5767008987549576E-16
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    21.222186003028806
#  Step length    5.7657026514068787E-007
# call:     3 Dx =   0.57657027E-06  Penalty function =  0.4107929045092911E-34
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.0018293137011029E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip8:1                      x            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip8:1                      px           4     0.00000000E+00    -3.65226906E-20     1.33390693E-35
# s.ds.r8.b1:1               x            4     0.00000000E+00     4.68856563E-19     2.19826477E-35
# s.ds.r8.b1:1               px           4     0.00000000E+00     1.02742208E-20     1.05559614E-36
#
#
# Final Penalty Function =   4.10792905e-35
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip8b1_acbyhs4.l8b1    8.99142e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b1_acbch5.l8b1    -4.04035e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b1_acbch6.r8b1    -9.88569e-06  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b1_acbyh4.r8b1     1.60831e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   4.10792905e-35
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999923662449803E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    96.154918677095779
#  Step length   0.99999973346184301
# call:     2 Dx =   0.99999973E+00  Penalty function =  0.4922195503152618E-15
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    96.154919297713491
#  Step length    2.2337259828480578E-006
# call:     3 Dx =   0.22337260E-05  Penalty function =  0.1055654338854417E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.0637971099664306E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip8:1                      x            4     1.00000000E-03     1.00000000E-03     4.23177966E-35
# ip8:1                      px           4     0.00000000E+00     2.33404048E-20     5.44774495E-36
# s.ds.r8.b2:1               x            4     0.00000000E+00     6.80435986E-19     4.62993132E-35
# s.ds.r8.b2:1               px           4     0.00000000E+00    -3.39125038E-20     1.15005791E-35
#
#
# Final Penalty Function =   1.05565434e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip8b2_acbyh4.l8b2     3.41347e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b2_acbyhs4.r8b2    9.22785e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b2_acbyh5.r8b2    -3.95300e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b2_acbchs5.l8b2   -3.95414e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.05565434e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999923664330158E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    103.07442062801624
#  Step length   0.99999972894804312
# call:     2 Dx =   0.99999973E+00  Penalty function =  0.9006242964848682E-16
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    103.07441967208779
#  Step length    9.4889844369637575E-007
# call:     3 Dx =   0.94889844E-06  Penalty function =  0.1815356204482240E-32
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.0630694124257885E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip8:1                      y            4     1.00000000E-03     1.00000000E-03     7.52316385E-35
# ip8:1                      py           4     0.00000000E+00     1.77620393E-20     3.15490040E-36
# s.ds.r8.b1:1               y            4     0.00000000E+00    -4.04983675E-18     1.64011777E-33
# s.ds.r8.b1:1               py           4     0.00000000E+00     9.84133603E-20     9.68518949E-35
#
#
# Final Penalty Function =   1.81535620e-33
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip8b1_acbyv4.l8b1     3.46179e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b1_acbyvs4.r8b1    9.18716e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b1_acbcvs5.l8b1   -3.94838e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b1_acbyv5.r8b1    -3.96721e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.81535620e-33
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000024721E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    42.803435481114001
#  Step length    1.0000003263338353
# call:     2 Dx =   0.10000003E+01  Penalty function =  0.5428938687325321E-26
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    42.803435480605906
#  Step length    1.3174752970796185E-012
# call:     3 Dx =   0.13174753E-11  Penalty function =  0.2919981614031281E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.0542623875618051E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip8:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip8:1                      py           4     0.00000000E+00    -2.18389396E-20     4.76939284E-36
# s.ds.r8.b2:1               y            4     0.00000000E+00     1.66111903E-18     2.75931645E-34
# s.ds.r8.b2:1               py           4     0.00000000E+00     2.56810172E-20     6.59514643E-36
#
#
# Final Penalty Function =   2.91998161e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip8b2_acbyvs5.r8b2   -4.03140e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b2_acbyvs4.l8b2    9.02341e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b2_acbyv4.r8b2     3.09654e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b2_acbcv5.l8b2    -4.03405e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   2.91998161e-34
# tar_on_xip1b1      =    1.387913597e-33 ;
# tar_on_xip1b2      =    1.358913953e-34 ;
# tar_on_yip1b1      =    1.069759568e-34 ;
# tar_on_yip1b2      =     1.32356918e-34 ;
# tar_on_xip2b1      =    2.239323982e-34 ;
# tar_on_xip2b2      =    9.930144275e-35 ;
# tar_on_yip2b1      =    1.505585473e-34 ;
# tar_on_yip2b2      =    2.496097971e-34 ;
# tar_on_xip5b1      =     6.42268809e-34 ;
# tar_on_xip5b2      =    5.818941597e-34 ;
# tar_on_yip5b1      =    1.413152247e-35 ;
# tar_on_yip5b2      =     3.42144576e-34 ;
# tar_on_xip8b1      =    4.107929045e-35 ;
# tar_on_xip8b2      =    1.055654339e-34 ;
# tar_on_yip8b1      =    1.815356204e-33 ;
# tar_on_yip8b2      =    2.919981614e-34 ;
# tar_lumiknob       =     6.32097821e-33 ;
# enter Twiss module
#
# iteration:   1 error:   6.949783E-18 deltap:   0.000000E+00
# orbit:   3.468109E-18 -1.235163E-19  0.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00
#
# ++++++ table: summ
#
#             length             orbit5               alfa            gammatr
#         26658.8832                 -0    0.0003475456429        53.64065544
#
#                 q1                dq1            betxmax              dxmax
#              62.31    -3.47472404e-11         591.188766        2.861358156
#
#              dxrms             xcomax             xcorms                 q2
#        1.494539569    5.991170862e-17     3.25282118e-17              60.32
#
#                dq2            betymax              dymax              dyrms
#     4.07704677e-11        640.9198357                  0                  0
#
#             ycomax             ycorms             deltap            synch_1
#                  0                  0                  0                  0
#
#            synch_2            synch_3            synch_4            synch_5
#                  0                  0                  0                  0
#
#            synch_6            synch_8             nflips              dqmin
#                  0                  0                  0                  0
#
#        dqmin_phase
#                  0
# @ NAME             %12s "TUNEKNOBS_B1"
# @ TYPE             %04s "USER"
# @ TITLE            %08s "no-title"
# @ ORIGIN           %17s "5.09.03 Darwin 64"
# @ DATE             %08s "07/05/25"
# @ TIME             %08s "17.49.16"
# *         KQTF.A12B1         KQTF.A23B1         KQTF.A34B1         KQTF.A45B1         KQTF.A56B1         KQTF.A67B1         KQTF.A78B1         KQTF.A81B1         KQTD.A12B1         KQTD.A23B1         KQTD.A34B1         KQTD.A45B1         KQTD.A56B1         KQTD.A67B1         KQTD.A78B1         KQTD.A81B1
# $                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le
#     0.0002804295004    0.0002804295004    0.0002804295004    0.0002804295004    0.0002804295004    0.0002804295004    0.0002804295004    0.0002804295004   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05
#     6.618040672e-05    6.618040672e-05    6.618040672e-05    6.618040672e-05    6.618040672e-05    6.618040672e-05    6.618040672e-05    6.618040672e-05   -0.0003348264218   -0.0003348264218   -0.0003348264218   -0.0003348264218   -0.0003348264218   -0.0003348264218   -0.0003348264218   -0.0003348264218
# enter Twiss module
#
# iteration:   1 error:   4.085048E-18 deltap:   0.000000E+00
# orbit:   1.656976E-18 -1.018445E-19  0.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00
#
# ++++++ table: summ
#
#             length             orbit5               alfa            gammatr
#         26658.8832                 -0    0.0003470470743        53.67917175
#
#                 q1                dq1            betxmax              dxmax
#              62.31    4.899992543e-11         601.155592        2.886801463
#
#              dxrms             xcomax             xcorms                 q2
#        1.493150456    6.963301192e-17    3.288705939e-17              60.32
#
#                dq2            betymax              dymax              dyrms
#   -1.189268296e-11        643.7015209                  0                  0
#
#             ycomax             ycorms             deltap            synch_1
#                  0                  0                  0                  0
#
#            synch_2            synch_3            synch_4            synch_5
#                  0                  0                  0                  0
#
#            synch_6            synch_8             nflips              dqmin
#                  0                  0                  0                  0
#
#        dqmin_phase
#                  0
# enter Twiss module
#
# iteration:   1 error:   2.432748E-03 deltap:   0.000000E+00
# orbit:  -1.155256E-03  5.197013E-06 -5.847659E-04  1.419717E-04  8.704697E-06 -5.078813E-07
#
# iteration:   2 error:   5.277199E-04 deltap:   0.000000E+00
# orbit:  -9.991268E-04 -8.136564E-08 -6.890271E-06  1.602341E-04  8.788919E-06  1.153105E-06
#
# iteration:   3 error:   1.392305E-05 deltap:   0.000000E+00
# orbit:  -9.999631E-04 -3.793412E-10  1.712213E-08  1.599994E-04  8.700213E-06  1.224447E-06
#
# iteration:   4 error:   5.380572E-10 deltap:   0.000000E+00
# orbit:  -9.999631E-04 -4.093793E-10  1.713940E-08  1.599994E-04  8.700205E-06  1.224460E-06
#
# ++++++ table: summ
#
#             length             orbit5               alfa            gammatr
#         26658.8832   -8.700205056e-06    0.0003475581534        53.63969002
#
#                 q1                dq1            betxmax              dxmax
#        62.31001209        9.977581633        591.1817428        2.753354799
#
#              dxrms             xcomax             xcorms                 q2
#        1.494651693     0.009621368585    0.0007691845485        60.32001224
#
#                dq2            betymax              dymax              dyrms
#        9.960711072        640.8949927       0.1578976117      0.04060295727
#
#             ycomax             ycorms             deltap            synch_1
#     0.007665077227    0.0006622670297                  0                  0
#
#            synch_2            synch_3            synch_4            synch_5
#                  0                  0                  0                  0
#
#            synch_6            synch_8             nflips              dqmin
#                  0                  0                  0    9.729486596e-08
#
#        dqmin_phase
#        1.604529003
# <Table 'twiss': {name, keyword, s, betx, alfx, mux, bety, alfy, muy, x, px, y, py, t, pt, dx, dpx, dy, dpy, wx, phix, dmux, wy, phiy, dmuy, ddx, ddpx, ddy, ddpy, r11, r12, r21, r22, energy, l, angle, k0l, k0sl, k1l, k1sl, k2l, k2sl, k3l, k3sl, k4l, k4sl, k5l, k5sl, k6l, k6sl, k7l, k7sl, k8l, k8sl, k9l, k9sl, k10l, k10sl, k11l, k11sl, k12l, k12sl, k13l, k13sl, k14l, k14sl, k15l, k15sl, k16l, k16sl, k17l, k17sl, k18l, k18sl, k19l, k19sl, k20l, k20sl, ksi, hkick, vkick, tilt, e1, e2, h1, h2, hgap, fint, fintx, volt, lag, freq, harmon, slot_id, assembly_id, mech_sep, v_pos, bbcharge, xma, yma, sigx, sigy, lrad, parent, comments, re11, re12, re13, re14, re15, re16, re21, re22, re23, re24, re25, re26, re31, re32, re33, re34, re35, re36, re41, re42, re43, re44, re45, re46, re51, re52, re53, re54, re55, re56, re61, re62, re63, re64, re65, re66, kmax, kmin, calib, polarity, alfa, beta11, beta12, beta13, beta21, beta22, beta23, beta31, beta32, beta33, alfa11, alfa12, alfa13, alfa21, alfa22, alfa23, alfa31, alfa32, alfa33, gama11, gama12, gama13, gama21, gama22, gama23, gama31, gama32, gama33, beta11p, beta12p, beta13p, beta21p, beta22p, beta23p, beta31p, beta32p, beta33p, alfa11p, alfa12p, alfa13p, alfa21p, alfa22p, alfa23p, alfa31p, alfa32p, alfa33p, gama11p, gama12p, gama13p, gama21p, gama22p, gama23p, gama31p, gama32p, gama33p, disp1, disp2, disp3, disp4, disp1p, disp2p, disp3p, disp4p, disp1p2, disp2p2, disp3p2, disp4p2, disp1p3, disp2p3, disp3p3, disp4p3, mu1, mu2, mu3, sig11, sig12, sig13, sig14, sig15, sig16, sig21, sig22, sig23, sig24, sig25, sig26, sig31, sig32, sig33, sig34, sig35, sig36, sig41, sig42, sig43, sig44, sig45, sig46, sig51, sig52, sig53, sig54, sig55, sig56, sig61, sig62, sig63, sig64, sig65, sig66, n1}>

# %%
mymad.input(f''' 
    Xangh:=-200.*on_x8h-100*on_x8hb; Xangv:= 200.*on_x8v;
    Pseph:= 1.00*on_sep8h; Psepv:=-1.00*on_sep8v;
    Xangs:=-10.*on_a8; Psepx:=0.50*on_o8; 
    offseth:=1.0*on_oh8; offsetv:= 1.0*on_ov8;
    ''')
mymad.input('value, scale0, on_x8h, on_sep8h, on_sep8v, on_xip8b1;')
mymad.input('value, acbxh1.l8, acbxh1.r8;')

# %%
mymad.input(f'''
    show, acbxh1.l8, acbxh2.l8, acbxh3.l8;
    show, acbxh1.r8, acbxh2.r8, acbxh3.r8;
    ''')

# %%
# ---  create new knob on_x8hb : adds on top of on_x8h to boost the crossing to 300 urad 
#      acts only on B1

# on_x8h runs from 0 to -200; 
# on_x8hb runs from 0 to -100; so combined run to -300 urad

# for Q4 the contribution of the on_x8h beyond -200 is removed by the on_x8hb ramping to -100 

mymad.input(f'''
    add2expr, var=acbyhs4.l8b1, expr=acbyhs4.l8b1xb*on_x8hb;
    add2expr, var=acbyhs4.r8b1, expr=acbyhs4.r8b1xb*on_x8hb;
    add2expr, var=acbyhs4.l8b2, expr=acbyhs4.l8b2xb*on_x8hb;
    add2expr, var=acbyhs4.r8b2, expr=acbyhs4.r8b2xb*on_x8hb;
    
    add2expr, var=acbchs5.l8b1, expr=acbchs5.l8b1xb*on_x8hb;
    add2expr, var=acbyhs5.r8b1, expr=acbyhs5.r8b1xb*on_x8hb;
    add2expr, var=acbchs5.l8b2, expr=acbchs5.l8b2xb*on_x8hb;
    add2expr, var=acbyhs5.r8b2, expr=acbyhs5.r8b2xb*on_x8hb;
    add2expr, var=acbch5.l8b1, expr=acbch5.l8b1xb*on_x8hb;
    add2expr, var=acbwh5.l8b1, expr=acbwh5.l8b1xb*on_x8hb;
    
    add2expr, var=acbch6.r8b1,  expr=acbch6.r8b1xb*on_x8hb;

    ''')

# %%
mymad.input(f'''
            
    scale0 :=1;
    limitMCBXH:=  63.5988*1.e-6*scale0;
    limitMCBXV:=  67.0164*1.e-6*scale0;
    limitMCBY :=  96.3*1.e-6*scale0;
    limitMCB  :=  80.8*1.e-6*scale0;
    limitMCBC :=  89.87*1.e-6*scale0;
    limitMCBW :=  80.14*1.e-6*scale0;
    limitMCBC_1.9K := 119.95*1.e-6*scale0;

    
    use, period=lhcb1,range=s.ds.l8.b1/e.ds.r8.b1;
    
    acbyhs4.r8b1xb := 0; acbch6.r8b1xb := 0;
 
       
    on_x8hb = 1;
    on_x8h=1; ! this is required in order to have the MCBX preset
    on_sep8v=1;on_x8v=0;on_sep8h=0;on_a8=0;on_o8=0;on_oh8=0;on_ov8=0;
        
    match, sequence=lhcb1,orbit, betx=1, bety=1, x=0, y=0, px=0, py=0;
    weight, x=1, px=10, y=1, py=10;
    
    constraint, sequence=lhcb1,range=ip8, x  =   0.001*Pseph + 0.001*Psepx + 0.001*offseth,
                                            y  =   0.001*Psepv  + 0.001*offsetv,
                                            px =   0.000001*Xangh,
				                            py =   0.000001*Xangv + 0.000001*Xangs;
    constraint, sequence=lhcb1,range=E.DS.R8.B1,x = 0.0, px = 0.0;
    constraint, sequence=lhcb1,range=E.DS.R8.B1,y = 0.0, py = 0.0;

    vary, name=acbyhs4.l8b1xb, step=1.e-5;
    vary, name=acbyhs4.r8b1xb, step=1.e-5;
    vary, name=acbyvs4.l8b1s, step=1.0e-5;
    vary, name=acbyvs4.r8b1s, step=1.0e-5;
    
    vary, name=acbchs5.l8b1x, step=1.e-5;
    # !vary, name=acbyhs5.r8b1x, step=1.e-5;
    vary, name=acbcvs5.l8b1s, step=1.e-5;
    vary, name=acvyvs5.r8b1s, step=1.e-5;
    
    vary, name=acbch6.r8b1xb,  step=1.e-5;
    lmdif, calls = 2000, tolerance=1.e-41;
    endmatch;
    ''')

# %%
import sys
sys.path.append('/Users/iliasefthymiopoulos/Work/lhc-special-optics/soptlib')

import soptlib 
soptlib.__version__
pm = soptlib.pm
print(f' --- loaded pmadx version {pm.__version__}')

# %%
nir=8
mymad.globals['on_x8hb'] = 100
mymad.globals['on_x8h'] = 200
mymad.globals['on_sep8v'] = 0
mymad.globals['on_x8h'] = 0
mymad.globals['on_xip8b1'] = 0

mymad.input('value, on_x8hb;')
_tt, _ss = pm.twissLHC(mymad)
print(_ss[['q1','q2']])

ipbetas = soptlib.get_beta_star_at_ip(_tt)
pprint.pprint(ipbetas)

betxip8 = ipbetas['lhcb1']['ip8']['betx'] 
ax = _tt.loc['s.ds.l8.b1':'e.ds.r8.b1'].plot(x='s',y='x')
_tt.loc['s.ds.l8.b1':'e.ds.r8.b1'].plot(x='s',y='y', color='red', ax=ax)
ax.axhline(mymad.globals['on_sep8h']*1.0e-3, color='magenta', linestyle='--')
ax.axvline(_tt.loc['ip8'].s[0], color='green')
print(f' -- ip location {_tt.loc["ip8"].s[0]}')
ax.set_title(f'VdM - IP{nir} b*={betxip8} on_sep8h={mymad.globals["on_sep8h"]}, on_x8h={mymad.globals["on_x8h"]} on_x8hb={mymad.globals["on_x8hb"]}')
ax.grid()

# %%
_ttb1 = _tt[_tt.beam == 'lhcb1']
_ipos_ip8 = [i for i,k in enumerate(_ttb1.index.values) if 'ip8' in k][0]
print(_ipos_ip8)
_dfy = _ttb1.iloc[_ipos_ip8-10:_ipos_ip8+10][['s','name','x','y']].copy()
_dfy['sip'] = _dfy['s'].apply(lambda r : r - _dfy.loc['ip8'].s)
_dfy['xip'] = _dfy['x'].apply(lambda r : r - _dfy.loc['ip8'].x)
_dfy['x-ang'] = np.arctan2(_dfy.xip, _dfy.sip)

_dfy

# %%
mymad.input('show, acbyhs4.r8b1;')

# %%
mymad.globals['acbyhs5.r8b1']

# %%
if 0:
    _cir = opt50m.circuits.madname['acbyhs5.r8b1']
    _cir.get_klimits(pc=6.8e12)
    for k,v in opt50m.ir8.strengths.items():
        _cir = opt50m.circuits.madname[k]
        print(f' --- {k=} : {_cir=} : {v=} {_cir.get_klimits(pc=6.8e12)}')

# %%
if 0 : 
    for k,v in opt50m.ir8.strengths.items():
        _cir = opt50m.circuits.madname[k]
        if not k.startswith('a'):
            continue
        if v != 0:
            _ic = _cir.get_current(abs(v))
        else:
            _ic = 0
        print(k,v, _ic)
        assert _cir.imin < _cir.get_current(v) < _cir.imax, f'Out of range {k=}, {v=}, {_ic=} {_cir.imin=}, {_cir.imax=}'

# %%
print(f'--- : on_xh8h:')
pprint.pprint(opt50m.ir8.knobs['on_x8h'].weights)
print(f'--- : on_xh8v:')
pprint.pprint(opt50m.ir8.knobs['on_x8v'].weights)

# %% [markdown]
# ## Check new optics files with MAD-x

# %%
import sys
sys.path.append('/Users/iliasefthymiopoulos/Work/lhc-special-optics/soptlib')

import soptlib 
soptlib.__version__
pm = soptlib.pm
print(f' --- loaded pmadx version {pm.__version__}')
# Out:
# sopt_plot.py:2025-05-07 17:49:50 PM:DEBUG -  -- loading module version 1.23 @ 09.02.2024 14:54
#  --- loaded pmadx version 1.2 @ 16.07.2023

# %%
from cpymad.madx import Madx

mymad  = Madx()
mymad.options['echo'] = False
mymad.options['warn'] = False
mymad.options['info'] = False
# mymad.call("acc-models-lhc/scenarios/cycle/vdm/desqueeze/111/model.madx")  # 50m 
# mymad.call("acc-models-lhc/scenarios/cycle/vdm/desqueeze/84/model.madx") # 44m
mymad.call("acc-models-lhc/scenarios/cycle/vdm/desqueeze/42/model.madx") # 34m
mymad.use('lhcb1')

mymad.twiss()
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.09.03  (64 bit, Darwin)      +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2024.04.25               +
#   + Execution date: 2025.05.07 17:50:14      +
#   ++++++++++++++++++++++++++++++++++++++++++++
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000076924E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.517240639264600
#  Step length    1.0000002894742086
# call:     2 Dx =   0.10000003E+01  Penalty function =  0.2213740125899274E-18
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.517240410931016
#  Step length    3.3516109778406615E-008
# call:     3 Dx =   0.33516110E-07  Penalty function =  0.1387913597137809E-32
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.2665363123383797E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip1:1                      x            4     1.00000000E-03     1.00000000E-03     1.69271187E-34
# ip1:1                      px           4     0.00000000E+00     9.21587802E-21     8.49324077E-37
# s.ds.r1.b1:1               x            4     0.00000000E+00    -3.41370673E-18     1.16533937E-33
# s.ds.r1.b1:1               px           4     0.00000000E+00     7.24249405E-20     5.24537200E-35
#
#
# Final Penalty Function =   1.38791360e-33
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip1b1_acbch5.r1b1    -7.44869e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b1_acbyhs4.r1b1    1.34866e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b1_acbch6.l1b1    -2.96467e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b1_acbyh4.l1b1     3.34012e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.38791360e-33
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000077162E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    17.644947271671263
#  Step length   0.99999980971476343
# call:     2 Dx =   0.99999981E+00  Penalty function =  0.1026633670254901E-17
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    17.644946314972366
#  Step length    6.0634117850894120E-008
# call:     3 Dx =   0.60634118E-07  Penalty function =  0.1358913953024163E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.2049648522409070E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip1:1                      x            4     1.00000000E-03     1.00000000E-03     1.88079096E-35
# ip1:1                      px           4     0.00000000E+00    -2.50131439E-20     6.25657370E-36
# s.ds.r1.b2:1               x            4     0.00000000E+00     1.05161829E-18     1.10590102E-34
# s.ds.r1.b2:1               px           4     0.00000000E+00    -4.86631250E-21     2.36809974E-37
#
#
# Final Penalty Function =   1.35891395e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip1b2_acbyh4.r1b2     4.01147e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b2_acbch6.r1b2    -3.17901e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b2_acbyhs4.l1b2    1.18548e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip1b2_acbch5.l1b2    -6.63913e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.35891395e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999964465944447E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    17.259373942634671
#  Step length   0.99999943290506721
# call:     2 Dx =   0.99999943E+00  Penalty function =  0.1068419779395480E-14
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    17.259325739794658
#  Step length    3.2686651810078803E-006
# call:     3 Dx =   0.32686652E-05  Penalty function =  0.1069759568187360E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.2104957806211875E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip1:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip1:1                      py           4     0.00000000E+00    -5.98199250E-21     3.57842342E-37
# s.ds.r1.b1:1               y            4     0.00000000E+00     9.33589977E-19     8.71590244E-35
# s.ds.r1.b1:1               py           4     0.00000000E+00     3.84149875E-20     1.47571127E-35
#
#
# Final Penalty Function =   1.06975957e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip1b1_acbyvs4.l1b1    1.21762e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b1_acbcv5.l1b1    -6.62022e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b1_acbyv4.r1b1     3.56165e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b1_acbcv6.r1b1    -3.15259e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.06975957e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000078776E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    68.569041201396388
#  Step length    1.0000002958021508
# call:     2 Dx =   0.10000003E+01  Penalty function =  0.3673755598056369E-26
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    68.569041202705989
#  Step length    1.4807967154571601E-011
# call:     3 Dx =   0.14807967E-10  Penalty function =  0.1323569179942764E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.2617088396948689E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip1:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip1:1                      py           4     0.00000000E+00    -2.35072761E-20     5.52592030E-36
# s.ds.r1.b2:1               y            4     0.00000000E+00     1.09837677E-18     1.20643152E-34
# s.ds.r1.b2:1               py           4     0.00000000E+00    -1.21896199E-20     1.48586834E-36
#
#
# Final Penalty Function =   1.32356918e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip1b2_acbcv5.r1b2    -7.49614e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b2_acbyv4.l1b2     3.79015e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b2_acbcv6.l1b2    -3.00581e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip1b2_acbyvs4.r1b2    1.31843e-04  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.32356918e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000028551E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    54.092573162741509
#  Step length    1.0000003757806313
# call:     2 Dx =   0.10000004E+01  Penalty function =  0.3310329776652783E-17
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    54.092574338805051
#  Step length    7.1298681588706271E-008
# call:     3 Dx =   0.71298682E-07  Penalty function =  0.2239323981838080E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.2009723824283166E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip2:1                      x            4     1.00000000E-03     1.00000000E-03     1.88079096E-35
# ip2:1                      px           4     0.00000000E+00     3.35518625E-20     1.12572748E-35
# s.ds.r2.b1:1               x            4     0.00000000E+00     1.39142915E-18     1.93607508E-34
# s.ds.r2.b1:1               px           4     0.00000000E+00    -5.09612908E-21     2.59705316E-37
#
#
# Final Penalty Function =   2.23932398e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip2b1_acbchs5.r2b1   -7.81747e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b1_acbyhs4.l2b1    9.47017e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b1_acbyh5.l2b1    -4.23129e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b1_acbyh4.r2b1     6.27153e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   2.23932398e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999949617367454E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    78.008428748807816
#  Step length   0.99999976304108440
# call:     2 Dx =   0.99999976E+00  Penalty function =  0.2731080537102912E-16
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    78.008435755300937
#  Step length    4.6727465402543123E-007
# call:     3 Dx =   0.46727465E-06  Penalty function =  0.9930144275496321E-34
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.1483826483753181E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip2:1                      x            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip2:1                      px           4     0.00000000E+00     7.25471712E-21     5.26309204E-37
# s.ds.r2.b2:1               x            4     0.00000000E+00    -9.66127745E-19     9.33402820E-35
# s.ds.r2.b2:1               px           4     0.00000000E+00     8.56080673E-21     7.32874118E-37
#
#
# Final Penalty Function =   9.93014428e-35
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip2b2_acbyh4.l2b2     4.12117e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b2_acbch5.r2b2    -4.79097e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b2_acbyhs4.r2b2    1.04617e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip2b2_acbyhs5.l2b2   -4.95318e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   9.93014428e-35
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000164995E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    78.784560396640387
#  Step length    1.0000002779198049
# call:     2 Dx =   0.10000003E+01  Penalty function =  0.1232856975781770E-24
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    78.784560396228287
#  Step length    5.9146373227027405E-012
# call:     3 Dx =   0.59146373E-11  Penalty function =  0.1505585473337026E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.1462081394757960E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip2:1                      y            4     1.00000000E-03     1.00000000E-03     1.17549435E-34
# ip2:1                      py           4     0.00000000E+00    -4.84775533E-20     2.35007318E-35
# s.ds.r2.b1:1               y            4     0.00000000E+00    -2.75981996E-19     7.61660622E-36
# s.ds.r2.b1:1               py           4     0.00000000E+00    -1.37541785E-20     1.89177425E-36
#
#
# Final Penalty Function =   1.50558547e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip2b1_acbcv5.r2b1    -4.79703e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b1_acbyv4.l2b1     4.01622e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b1_acbyvs5.l2b1   -4.96566e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b1_acbyvs4.r2b1    1.04310e-04  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.50558547e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000032380E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.810009121637187
#  Step length    1.0000003790504097
# call:     2 Dx =   0.10000004E+01  Penalty function =  0.5767839823467374E-24
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.810009116237374
#  Step length    6.0869043809151890E-011
# call:     3 Dx =   0.60869044E-10  Penalty function =  0.2496097971148733E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.1987203539222942E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip2:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip2:1                      py           4     0.00000000E+00    -2.21636513E-20     4.91227437E-36
# s.ds.r2.b2:1               y            4     0.00000000E+00    -1.54435417E-18     2.38502981E-34
# s.ds.r2.b2:1               py           4     0.00000000E+00     1.22170566E-20     1.49256473E-36
#
#
# Final Penalty Function =   2.49609797e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip2b2_acbcvs5.r2b2   -7.82651e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b2_acbyv4.r2b2     6.21833e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b2_acbyv5.l2b2    -4.24268e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip2b2_acbyvs4.l2b2    9.41035e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   2.49609797e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999963404679191E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.545842095894059
#  Step length    1.0000000894166667
# call:     2 Dx =   0.10000001E+01  Penalty function =  0.1182630987840349E-15
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    61.545837252841878
#  Step length    1.0359415252519416E-006
# call:     3 Dx =   0.10359415E-05  Penalty function =  0.6422688089840390E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.3407936399166421E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip5:1                      x            4     1.00000000E-03     1.00000000E-03     1.88079096E-35
# ip5:1                      px           4     0.00000000E+00    -2.11748216E-20     4.48373070E-36
# s.ds.r5.b1:1               x            4     0.00000000E+00     2.38327343E-18     5.67999224E-34
# s.ds.r5.b1:1               px           4     0.00000000E+00    -7.13988409E-20     5.09779448E-35
#
#
# Final Penalty Function =   6.42268809e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip5b1_acbch6.l5b1    -2.88979e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b1_acbyhs4.r5b1    1.28218e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b1_acbyh4.l5b1     6.99607e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b1_acbch5.r5b1    -1.00741e-04  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   6.42268809e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000022028E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    21.789592276545797
#  Step length    1.0000000675672414
# call:     2 Dx =   0.10000001E+01  Penalty function =  0.1964563792990796E-17
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    21.789591414341842
#  Step length    2.5374696050969896E-008
# call:     3 Dx =   0.25374696E-07  Penalty function =  0.5818941596654206E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.4246058542161809E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip5:1                      x            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip5:1                      px           4     0.00000000E+00     4.42011535E-20     1.95374197E-35
# s.ds.r5.b2:1               x            4     0.00000000E+00     2.36141381E-18     5.57627519E-34
# s.ds.r5.b2:1               px           4     0.00000000E+00    -1.65057625E-21     2.72440194E-38
#
#
# Final Penalty Function =   5.81894160e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip5b2_acbch6.r5b2    -2.78301e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b2_acbyh4.r5b2     6.80301e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b2_acbch5.l5b2    -1.15589e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip5b2_acbyhs4.l5b2    1.49751e-04  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   5.81894160e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999966300695303E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    22.030165450302075
#  Step length   0.99999963627005894
# call:     2 Dx =   0.99999964E+00  Penalty function =  0.8157938043624313E-15
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    22.030227259440384
#  Step length    2.8561947748349392E-006
# call:     3 Dx =   0.28561948E-05  Penalty function =  0.1413152246774501E-34
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.4244504749533352E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip5:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip5:1                      py           4     0.00000000E+00    -1.01794865E-20     1.03621945E-36
# s.ds.r5.b1:1               y            4     0.00000000E+00     2.89571843E-19     8.38518525E-36
# s.ds.r5.b1:1               py           4     0.00000000E+00    -9.02239897E-22     8.14036832E-39
#
#
# Final Penalty Function =   1.41315225e-35
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip5b1_acbyvs4.l5b1    1.49750e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b1_acbcv6.r5b1    -2.79728e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b1_acbyv4.r5b1     6.78407e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b1_acbcv5.l5b1    -1.15589e-04  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.41315225e-35
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000086174E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    62.109222660573863
#  Step length   0.99999960378971209
# call:     2 Dx =   0.99999960E+00  Penalty function =  0.1323222070894019E-23
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    62.109222660526328
#  Step length    1.3468965494437679E-011
# call:     3 Dx =   0.13468965E-10  Penalty function =  0.3421445760078814E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.3411894791590573E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip5:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip5:1                      py           4     0.00000000E+00     2.51207178E-20     6.31050465E-36
# s.ds.r5.b2:1               y            4     0.00000000E+00    -1.81968263E-18     3.31124486E-34
# s.ds.r5.b2:1               py           4     0.00000000E+00    -8.72235820E-22     7.60795326E-39
#
#
# Final Penalty Function =   3.42144576e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip5b2_acbyvs4.r5b2    1.28200e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b2_acbcv5.r5b2    -1.00887e-04  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b2_acbcv6.l5b2    -2.87307e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip5b2_acbyv4.l5b2     7.01254e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   3.42144576e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999947115297058E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    21.222175823602395
#  Step length   0.99999910740895437
# call:     2 Dx =   0.99999911E+00  Penalty function =  0.5767008987549576E-16
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    21.222186003028806
#  Step length    5.7657026514068787E-007
# call:     3 Dx =   0.57657027E-06  Penalty function =  0.4107929045092911E-34
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.0018293137011029E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip8:1                      x            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip8:1                      px           4     0.00000000E+00    -3.65226906E-20     1.33390693E-35
# s.ds.r8.b1:1               x            4     0.00000000E+00     4.68856563E-19     2.19826477E-35
# s.ds.r8.b1:1               px           4     0.00000000E+00     1.02742208E-20     1.05559614E-36
#
#
# Final Penalty Function =   4.10792905e-35
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip8b1_acbyhs4.l8b1    8.99142e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b1_acbch5.l8b1    -4.04035e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b1_acbch6.r8b1    -9.88569e-06  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b1_acbyh4.r8b1     1.60831e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   4.10792905e-35
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999923662449803E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    96.154918677095779
#  Step length   0.99999973346184301
# call:     2 Dx =   0.99999973E+00  Penalty function =  0.4922195503152618E-15
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    96.154919297713491
#  Step length    2.2337259828480578E-006
# call:     3 Dx =   0.22337260E-05  Penalty function =  0.1055654338854417E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.0637971099664306E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip8:1                      x            4     1.00000000E-03     1.00000000E-03     4.23177966E-35
# ip8:1                      px           4     0.00000000E+00     2.33404048E-20     5.44774495E-36
# s.ds.r8.b2:1               x            4     0.00000000E+00     6.80435986E-19     4.62993132E-35
# s.ds.r8.b2:1               px           4     0.00000000E+00    -3.39125038E-20     1.15005791E-35
#
#
# Final Penalty Function =   1.05565434e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_xip8b2_acbyh4.l8b2     3.41347e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b2_acbyhs4.r8b2    9.22785e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b2_acbyh5.r8b2    -3.95300e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_xip8b2_acbchs5.l8b2   -3.95414e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.05565434e-34
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb1
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.9999923664330158E-04
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    103.07442062801624
#  Step length   0.99999972894804312
# call:     2 Dx =   0.99999973E+00  Penalty function =  0.9006242964848682E-16
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    103.07441967208779
#  Step length    9.4889844369637575E-007
# call:     3 Dx =   0.94889844E-06  Penalty function =  0.1815356204482240E-32
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.0630694124257885E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip8:1                      y            4     1.00000000E-03     1.00000000E-03     7.52316385E-35
# ip8:1                      py           4     0.00000000E+00     1.77620393E-20     3.15490040E-36
# s.ds.r8.b1:1               y            4     0.00000000E+00    -4.04983675E-18     1.64011777E-33
# s.ds.r8.b1:1               py           4     0.00000000E+00     9.84133603E-20     9.68518949E-35
#
#
# Final Penalty Function =   1.81535620e-33
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip8b1_acbyv4.l8b1     3.46179e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b1_acbyvs4.r8b1    9.18716e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b1_acbcvs5.l8b1   -3.94838e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b1_acbyv5.r8b1    -3.96721e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   1.81535620e-33
# START MATCHING
#
# number of sequences: 1
# sequence name: lhcb2
# entry name: betx
# number of entries: 1
# entry value: 1.000000
# entry name: bety
# number of entries: 1
# entry value: 1.000000
# number of variables:    4
# user given constraints: 1
# total constraints:      4
#
# START JACOBIAN:
#
#  JACOBIAN Strategy =           3
# Initial Penalty Function =   0.1000000000024721E-03
#
#
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    42.803435481114001
#  Step length    1.0000003263338353
# call:     2 Dx =   0.10000003E+01  Penalty function =  0.5428938687325321E-26
#  Solve system with            4 con,           4 var
#  Rank             4   Condition number    42.803435480605906
#  Step length    1.3174752970796185E-012
# call:     3 Dx =   0.13174753E-11  Penalty function =  0.2919981614031281E-33
#  ++++++++++ JACOBIAN ended: converged successfully
#  Final difference norm:   1.0542623875618051E-002
#
# MATCH SUMMARY
#
# Node_Name                  Constraint   Type  Target Value       Final Value        Penalty
# --------------------------------------------------------------------------------------------------
# ip8:1                      y            4     1.00000000E-03     1.00000000E-03     4.70197740E-36
# ip8:1                      py           4     0.00000000E+00    -2.18389396E-20     4.76939284E-36
# s.ds.r8.b2:1               y            4     0.00000000E+00     1.66111903E-18     2.75931645E-34
# s.ds.r8.b2:1               py           4     0.00000000E+00     2.56810172E-20     6.59514643E-36
#
#
# Final Penalty Function =   2.91998161e-34
#
#
#
#
#
# Variable                 Final Value  Initial Value Lower Limit  Upper Limit
# --------------------------------------------------------------------------------
# on_yip8b2_acbyvs5.r8b2   -4.03140e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b2_acbyvs4.l8b2    9.02341e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b2_acbyv4.r8b2     3.09654e-05  0.00000e+00 -1.00000e+20  1.00000e+20
# on_yip8b2_acbcv5.l8b2    -4.03405e-05  0.00000e+00 -1.00000e+20  1.00000e+20
#
# END MATCH SUMMARY
#
# VARIABLE "TAR" SET TO   2.91998161e-34
# tar_on_xip1b1      =    1.387913597e-33 ;
# tar_on_xip1b2      =    1.358913953e-34 ;
# tar_on_yip1b1      =    1.069759568e-34 ;
# tar_on_yip1b2      =     1.32356918e-34 ;
# tar_on_xip2b1      =    2.239323982e-34 ;
# tar_on_xip2b2      =    9.930144275e-35 ;
# tar_on_yip2b1      =    1.505585473e-34 ;
# tar_on_yip2b2      =    2.496097971e-34 ;
# tar_on_xip5b1      =     6.42268809e-34 ;
# tar_on_xip5b2      =    5.818941597e-34 ;
# tar_on_yip5b1      =    1.413152247e-35 ;
# tar_on_yip5b2      =     3.42144576e-34 ;
# tar_on_xip8b1      =    4.107929045e-35 ;
# tar_on_xip8b2      =    1.055654339e-34 ;
# tar_on_yip8b1      =    1.815356204e-33 ;
# tar_on_yip8b2      =    2.919981614e-34 ;
# tar_lumiknob       =     6.32097821e-33 ;
# enter Twiss module
#
# iteration:   1 error:   6.949783E-18 deltap:   0.000000E+00
# orbit:   3.468109E-18 -1.235163E-19  0.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00
#
# ++++++ table: summ
#
#             length             orbit5               alfa            gammatr
#         26658.8832                 -0    0.0003475456429        53.64065544
#
#                 q1                dq1            betxmax              dxmax
#              62.31    -3.47472404e-11         591.188766        2.861358156
#
#              dxrms             xcomax             xcorms                 q2
#        1.494539569    5.991170862e-17     3.25282118e-17              60.32
#
#                dq2            betymax              dymax              dyrms
#     4.07704677e-11        640.9198357                  0                  0
#
#             ycomax             ycorms             deltap            synch_1
#                  0                  0                  0                  0
#
#            synch_2            synch_3            synch_4            synch_5
#                  0                  0                  0                  0
#
#            synch_6            synch_8             nflips              dqmin
#                  0                  0                  0                  0
#
#        dqmin_phase
#                  0
# @ NAME             %12s "TUNEKNOBS_B1"
# @ TYPE             %04s "USER"
# @ TITLE            %08s "no-title"
# @ ORIGIN           %17s "5.09.03 Darwin 64"
# @ DATE             %08s "07/05/25"
# @ TIME             %08s "17.50.16"
# *         KQTF.A12B1         KQTF.A23B1         KQTF.A34B1         KQTF.A45B1         KQTF.A56B1         KQTF.A67B1         KQTF.A78B1         KQTF.A81B1         KQTD.A12B1         KQTD.A23B1         KQTD.A34B1         KQTD.A45B1         KQTD.A56B1         KQTD.A67B1         KQTD.A78B1         KQTD.A81B1
# $                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le                %le
#     0.0002804295004    0.0002804295004    0.0002804295004    0.0002804295004    0.0002804295004    0.0002804295004    0.0002804295004    0.0002804295004   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05   -4.895910436e-05
#     6.618040672e-05    6.618040672e-05    6.618040672e-05    6.618040672e-05    6.618040672e-05    6.618040672e-05    6.618040672e-05    6.618040672e-05   -0.0003348264218   -0.0003348264218   -0.0003348264218   -0.0003348264218   -0.0003348264218   -0.0003348264218   -0.0003348264218   -0.0003348264218
# enter Twiss module
#
# iteration:   1 error:   4.085048E-18 deltap:   0.000000E+00
# orbit:   1.656976E-18 -1.018445E-19  0.000000E+00  0.000000E+00  0.000000E+00  0.000000E+00
#
# ++++++ table: summ
#
#             length             orbit5               alfa            gammatr
#         26658.8832                 -0    0.0003470470743        53.67917175
#
#                 q1                dq1            betxmax              dxmax
#              62.31    4.899992543e-11         601.155592        2.886801463
#
#              dxrms             xcomax             xcorms                 q2
#        1.493150456    6.963301192e-17    3.288705939e-17              60.32
#
#                dq2            betymax              dymax              dyrms
#   -1.189268296e-11        643.7015209                  0                  0
#
#             ycomax             ycorms             deltap            synch_1
#                  0                  0                  0                  0
#
#            synch_2            synch_3            synch_4            synch_5
#                  0                  0                  0                  0
#
#            synch_6            synch_8             nflips              dqmin
#                  0                  0                  0                  0
#
#        dqmin_phase
#                  0
# enter Twiss module
#
# iteration:   1 error:   2.432748E-03 deltap:   0.000000E+00
# orbit:  -1.155256E-03  5.197013E-06 -5.847659E-04  1.419717E-04  8.704697E-06 -5.078813E-07
#
# iteration:   2 error:   5.277199E-04 deltap:   0.000000E+00
# orbit:  -9.991268E-04 -8.136564E-08 -6.890271E-06  1.602341E-04  8.788919E-06  1.153105E-06
#
# iteration:   3 error:   1.392305E-05 deltap:   0.000000E+00
# orbit:  -9.999631E-04 -3.793412E-10  1.712213E-08  1.599994E-04  8.700213E-06  1.224447E-06
#
# iteration:   4 error:   5.380572E-10 deltap:   0.000000E+00
# orbit:  -9.999631E-04 -4.093793E-10  1.713940E-08  1.599994E-04  8.700205E-06  1.224460E-06
#
# ++++++ table: summ
#
#             length             orbit5               alfa            gammatr
#         26658.8832   -8.700205056e-06    0.0003475581534        53.63969002
#
#                 q1                dq1            betxmax              dxmax
#        62.31001209        9.977581633        591.1817428        2.753354799
#
#              dxrms             xcomax             xcorms                 q2
#        1.494651693     0.009621368585    0.0007691845485        60.32001224
#
#                dq2            betymax              dymax              dyrms
#        9.960711072        640.8949927       0.1578976117      0.04060295727
#
#             ycomax             ycorms             deltap            synch_1
#     0.007665077227    0.0006622670297                  0                  0
#
#            synch_2            synch_3            synch_4            synch_5
#                  0                  0                  0                  0
#
#            synch_6            synch_8             nflips              dqmin
#                  0                  0                  0    9.729486596e-08
#
#        dqmin_phase
#        1.604529003
# <Table 'twiss': {name, keyword, s, betx, alfx, mux, bety, alfy, muy, x, px, y, py, t, pt, dx, dpx, dy, dpy, wx, phix, dmux, wy, phiy, dmuy, ddx, ddpx, ddy, ddpy, r11, r12, r21, r22, energy, l, angle, k0l, k0sl, k1l, k1sl, k2l, k2sl, k3l, k3sl, k4l, k4sl, k5l, k5sl, k6l, k6sl, k7l, k7sl, k8l, k8sl, k9l, k9sl, k10l, k10sl, k11l, k11sl, k12l, k12sl, k13l, k13sl, k14l, k14sl, k15l, k15sl, k16l, k16sl, k17l, k17sl, k18l, k18sl, k19l, k19sl, k20l, k20sl, ksi, hkick, vkick, tilt, e1, e2, h1, h2, hgap, fint, fintx, volt, lag, freq, harmon, slot_id, assembly_id, mech_sep, v_pos, bbcharge, xma, yma, sigx, sigy, lrad, parent, comments, re11, re12, re13, re14, re15, re16, re21, re22, re23, re24, re25, re26, re31, re32, re33, re34, re35, re36, re41, re42, re43, re44, re45, re46, re51, re52, re53, re54, re55, re56, re61, re62, re63, re64, re65, re66, kmax, kmin, calib, polarity, alfa, beta11, beta12, beta13, beta21, beta22, beta23, beta31, beta32, beta33, alfa11, alfa12, alfa13, alfa21, alfa22, alfa23, alfa31, alfa32, alfa33, gama11, gama12, gama13, gama21, gama22, gama23, gama31, gama32, gama33, beta11p, beta12p, beta13p, beta21p, beta22p, beta23p, beta31p, beta32p, beta33p, alfa11p, alfa12p, alfa13p, alfa21p, alfa22p, alfa23p, alfa31p, alfa32p, alfa33p, gama11p, gama12p, gama13p, gama21p, gama22p, gama23p, gama31p, gama32p, gama33p, disp1, disp2, disp3, disp4, disp1p, disp2p, disp3p, disp4p, disp1p2, disp2p2, disp3p2, disp4p2, disp1p3, disp2p3, disp3p3, disp4p3, mu1, mu2, mu3, sig11, sig12, sig13, sig14, sig15, sig16, sig21, sig22, sig23, sig24, sig25, sig26, sig31, sig32, sig33, sig34, sig35, sig36, sig41, sig42, sig43, sig44, sig45, sig46, sig51, sig52, sig53, sig54, sig55, sig56, sig61, sig62, sig63, sig64, sig65, sig66, n1}>

# %%
nir=8
mymad.globals['on_x8h'] = -300
mymad.globals['on_sep8v'] = -1

mymad.input('value, on_x8h;')
_tt, _ss = pm.twissLHC(mymad)
print(_ss[['q1','q2']])

ipbetas = soptlib.get_beta_star_at_ip(_tt)
pprint.pprint(ipbetas)

betxip8 = ipbetas['lhcb1']['ip8']['betx'] 
ax = _tt.loc['s.ds.l8.b1':'e.ds.r8.b1'].plot(x='s',y='x')
_tt.loc['s.ds.l8.b1':'e.ds.r8.b1'].plot(x='s',y='y', color='red', ax=ax)
ax.axhline(mymad.globals['on_sep8h']*1.0e-3, color='magenta', linestyle='--')
ax.axvline(_tt.loc['ip8'].s[0], color='green')
print(f' -- ip location {_tt.loc["ip8"].s[0]}')
ax.set_title(f'VdM - IP{nir} b*={betxip8} on_sep8h={mymad.globals["on_sep8h"]}, on_x8h={mymad.globals["on_x8h"]}')
ax.grid()
# Out:
# on_x8h             =               -300 ;
# enter Twiss module
#
# iteration:   1 error:   2.432748E-03 deltap:   0.000000E+00
# orbit:  -1.155260E-03  5.197174E-06 -5.847576E-04  1.419719E-04  8.979586E-06 -4.294099E-07
#
# iteration:   2 error:   5.277169E-04 deltap:   0.000000E+00
# orbit:  -9.991139E-04 -8.135620E-08 -6.889207E-06  1.602341E-04  9.021170E-06  1.219475E-06
#
# iteration:   3 error:   1.392284E-05 deltap:   0.000000E+00
# orbit:  -9.999497E-04 -3.728495E-10  1.805251E-08  1.599994E-04  8.932821E-06  1.290914E-06
#
# iteration:   4 error:   5.380484E-10 deltap:   0.000000E+00
# orbit:  -9.999497E-04 -4.028878E-10  1.806977E-08  1.599994E-04  8.932812E-06  1.290926E-06
#
# ++++++ table: summ
#
#             length             orbit5               alfa            gammatr
#         26658.8832   -8.932812204e-06    0.0003475585389        53.63966027
#
#                 q1                dq1            betxmax              dxmax
#        62.31001272        9.973776073        591.1812833        2.744985462
#
#              dxrms             xcomax             xcorms                 q2
#        1.494972965      0.01448814413     0.001001106803         60.3200129
#
#                dq2            betymax              dymax              dyrms
#        9.945625607        640.8936988       0.1578973578      0.04060287401
#
#             ycomax             ycorms             deltap            synch_1
#     0.007665076481    0.0006622669523                  0                  0
#
#            synch_2            synch_3            synch_4            synch_5
#                  0                  0                  0                  0
#
#            synch_6            synch_8             nflips              dqmin
#                  0                  0                  0    1.005946809e-07
#
#        dqmin_phase
#        1.611278141
# enter Twiss module
#
# iteration:   1 error:   2.426382E-03 deltap:   0.000000E+00
# orbit:   1.080241E-03 -8.504133E-06  5.300735E-04 -1.478223E-04  1.132320E-05  5.677429E-07
#
# iteration:   2 error:   5.503884E-04 deltap:   0.000000E+00
# orbit:   9.993785E-04  9.227697E-09  4.926125E-06 -1.601895E-04  8.677912E-06  1.695726E-06
#
# iteration:   3 error:   1.028715E-05 deltap:   0.000000E+00
# orbit:   1.000023E-03  8.472509E-11 -2.848081E-09 -1.600020E-04  8.630198E-06  1.775013E-06
#
# iteration:   4 error:   5.877622E-11 deltap:   0.000000E+00
# orbit:   1.000023E-03  9.293753E-11 -2.827877E-09 -1.600020E-04  8.630198E-06  1.775020E-06
#
# ++++++ table: summ
#
#             length             orbit5               alfa            gammatr
#         26658.8832   -8.630197873e-06    0.0003470398993        53.67972666
#
#                 q1                dq1            betxmax              dxmax
#        62.31001753        9.980144481         601.125342        2.911014022
#
#              dxrms             xcomax             xcorms                 q2
#        1.494554977      0.01443200211     0.001014199168        60.32001778
#
#                dq2            betymax              dymax              dyrms
#        9.978708266        643.6625978        0.170632053      0.04896121394
#
#             ycomax             ycorms             deltap            synch_1
#     0.007665168203    0.0006648170116                  0                  0
#
#            synch_2            synch_3            synch_4            synch_5
#                  0                  0                  0                  0
#
#            synch_6            synch_8             nflips              dqmin
#                  0                  0                  0    1.826369399e-07
#
#        dqmin_phase
#       0.4556971781
#               q1         q2
# lhcb1  62.310013  60.320013
# lhcb2  62.310018  60.320018
# {'lhcb1': {'ip1': {'betx': 19.2, 'bety': 19.2},
#            'ip2': {'betx': 19.2, 'bety': 19.2},
#            'ip3': {'betx': 121.572, 'bety': 218.586},
#            'ip4': {'betx': 239.426, 'bety': 242.772},
#            'ip5': {'betx': 19.2, 'bety': 19.2},
#            'ip6': {'betx': 188.437, 'bety': 175.627},
#            'ip7': {'betx': 120.814, 'bety': 149.426},
#            'ip8': {'betx': 34.0, 'bety': 33.999}},
#  'lhcb2': {'ip1': {'betx': 19.2, 'bety': 19.2},
#            'ip2': {'betx': 19.2, 'bety': 19.2},
#            'ip3': {'betx': 121.572, 'bety': 218.586},
#            'ip4': {'betx': 239.426, 'bety': 242.772},
#            'ip5': {'betx': 19.2, 'bety': 19.2},
#            'ip6': {'betx': 188.437, 'bety': 175.627},
#            'ip7': {'betx': 120.814, 'bety': 149.426},
#            'ip8': {'betx': 34.0, 'bety': 33.999}}}
#  -- ip location 23315.378983621205
# /var/folders/v4/b86yc68134n5znh2b07bss740000gq/T/ipykernel_55596/351656836.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.axvline(_tt.loc['ip8'].s[0], color='green')
# /var/folders/v4/b86yc68134n5znh2b07bss740000gq/T/ipykernel_55596/351656836.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f' -- ip location {_tt.loc["ip8"].s[0]}')

# %%
# mymad.call(file="./data/vdmoptics_2025.11")
# mymad.call(file="./data/vdmoptics_2025.10")
mymad.call(file="./data/vdmoptics_2025.9")

# %%
mymad.input('show, acbch6.r8b1;')
mymad.input('show, acbyhs5.r8b1;')
# Out:
# acbch6.r8b1        := -0+6.83422896768483e-08*on_x8h-8.50061428443e-06*on_oh8-9.88568570403025e-06*on_xip8b1-4.36e-06*dp_trim.b1 ;
# acbyhs5.r8b1       := +0+9.9911110076893e-08*on_x8h+1.92415536697e-05*on_sep8h-3.84071305033e-05*on_o8-5.11766148732e-06*on_oh8 ;
# True

# %% [markdown]
# ## Add new knob in LHCOPTICS-obs
#
# - add the new knob and then match the normal x-ing knobs

# %%
opt50m.ir8.knobs['on_x8h']

# %%
import xtrack as xt
from lhcoptics import Knob


opt50m.knobs["on_x8h_bmp"]=Knob("on_xh8_bmp",0,{"kqx.l1": 32})

# %%
all_knobs_ip8 = [
        'acbxh1.l8', 'acbxh2.l8', 'acbxh3.l8',
        'acbxv1.l8', 'acbxv2.l8', 'acbxv3.l8', 
        
        'acbxh1.r8', 'acbxh2.r8', 'acbxh3.r8', 
        'acbxv1.r8', 'acbxv2.r8', 'acbxv3.r8',

        'acbyhs4.l8b1', 'acbyhs4.l8b2',
        'acbyvs4.l8b1', 'acbyvs4.l8b2', 
    
        'acbyhs4.r8b1'  'acbyhs4.r8b2',
        'acbyvs4.r8b1', 'acbyvs4.r8b2',
                
        'acbchs5.l8b1', 'acbchs5.l8b2',
        'acbcvs5.l8b1', 'acbcvs5.l8b2',
                    
        'acbyhs5.r8b1', 'acbyhs5.r8b2', 
        'acbyvs5.r8b1', 'acbyvs5.r8b2', 
            
        'xip8b1', 'yip8b1', 'pxip8b1', 'pyip8b1',
        'xip8b2', 'yip8b2', 'pxip8b2', 'pyip8b2',
    ]

# %%
collider = opt50m.model.env
collider.match_knob?

# %%
def match_xing_ip8(collider):
    
    all_knobs_ip8 = [
            'acbxh1.l8', 'acbxh2.l8', 'acbxh3.l8',
            'acbxv1.l8', 'acbxv2.l8', 'acbxv3.l8', 
            
            'acbxh1.r8', 'acbxh2.r8', 'acbxh3.r8', 
            'acbxv1.r8', 'acbxv2.r8', 'acbxv3.r8',

            'acbyhs4.l8b1', 'acbyhs4.l8b2',
            'acbyvs4.l8b1', 'acbyvs4.l8b2', 
       
            'acbyhs4.r8b1'  'acbyhs4.r8b2',
            'acbyvs4.r8b1', 'acbyvs4.r8b2',
                  
            'acbchs5.l8b1', 'acbchs5.l8b2',
            'acbcvs5.l8b1', 'acbcvs5.l8b2',
                       
            'acbyhs5.r8b1', 'acbyhs5.r8b2', 
            'acbyvs5.r8b1', 'acbyvs5.r8b2', 
             
            'xip8b1', 'yip8b1', 'pxip8b1', 'pyip8b1',
            'xip8b2', 'yip8b2', 'pxip8b2', 'pyip8b2',
        ]

    # kill all existing knobs
    for kk in all_knobs_ip8:
        collider.vars[kk] = 0

    twinit_zero_orbit = [xt.TwissInit(), xt.TwissInit()]

    targets_close_bump = [
        xt.TargetSet(line='lhcb1', at=xt.END, x=0, px=0, y=0, py=0),
        xt.TargetSet(line='lhcb2', at=xt.END, x=0, px=0, y=0, py=0),
    ]

    bump_range_ip8 = {
        'start': ['s.ds.l8.b1', 's.ds.l8.b2'],
        'end': ['e.ds.r8.b1', 'e.ds.r8.b2'],
    }

    correctors_ir8_single_beam_h = [
        'acbyhs4.l8b1', 'acbyhs4.r8b2', 'acbyhs4.l8b2', 'acbyhs4.r8b1',
        'acbchs5.l8b2', 'acbchs5.l8b1', 'acbyhs5.r8b1', 'acbyhs5.r8b2']

    correctors_ir8_single_beam_v = [
        'acbyvs4.l8b1', 'acbyvs4.r8b2', 'acbyvs4.l8b2', 'acbyvs4.r8b1',
        'acbcvs5.l8b2', 'acbcvs5.l8b1', 'acbyvs5.r8b1', 'acbyvs5.r8b2']

    correctors_ir8_common_h = [
        'acbxh1.l8', 'acbxh2.l8', 'acbxh3.l8', 'acbxh1.r8', 'acbxh2.r8', 'acbxh3.r8']

    correctors_ir8_common_v = [
        'acbxv1.l8', 'acbxv2.l8', 'acbxv3.l8', 'acbxv1.r8', 'acbxv2.r8', 'acbxv3.r8']


    ##############################
    # Match crossing angle knobs #
    ##############################

    angle_match_ip8 = 170e-6

    # ---------- on_x8h ----------

    opt_x8h = collider.match_knob(
        knob_name='on_x8h', knob_value_end=(angle_match_ip8 * 1e6),
        targets=(targets_close_bump + [
            xt.TargetSet(line='lhcb1', at='ip8',  x=0, px=angle_match_ip8),
            xt.TargetSet(line='lhcb2', at='ip8',  x=0, px=-angle_match_ip8),
        ]),
        vary=[
            xt.VaryList(correctors_ir8_single_beam_h),
            xt.VaryList(correctors_ir8_common_h, tag='mcbx')],
        run=False, init=twinit_zero_orbit, **bump_range_ip8,
    )

    # Set mcbx by hand (reduce value by 10, to test matching algorithm)
    testkqx8=abs(collider.varval['kqx.l8'])*7000./0.3
    acbx_xing_ir8 = 1.0e-6 if testkqx8 > 210. else 11.0e-6 # Value for 170 urad crossing

    # Set mcbx by hand
    for icorr in [1, 2, 3]:
        collider.vars[f'acbxh{icorr}.l8_from_on_x8h'] = acbx_xing_ir8 * angle_match_ip8 / 170e-6
        collider.vars[f'acbxh{icorr}.r8_from_on_x8h'] = -acbx_xing_ir8 * angle_match_ip8 / 170e-6

    #   (reduce value by 10, to test matching algorithm)
    #   collider.vars[f'acbxh{icorr}.l8_from_on_x8h'] = acbx_xing_ir8 * angle_match_ip8 / 170e-6 * 0.1
    #   collider.vars[f'acbxh{icorr}.r8_from_on_x8h'] = -acbx_xing_ir8 * angle_match_ip8 / 170e-6 * 0.1

    # First round of optimization without changing mcbx
    opt_x8h.disable_vary(tag='mcbx')
    opt_x8h.step(3) # perform 3 steps without checking for convergence

    # Link all mcbx strengths to the first one
    collider.vars['acbxh2.l8_from_on_x8h'] =  collider.vars['acbxh1.l8_from_on_x8h']
    collider.vars['acbxh3.l8_from_on_x8h'] =  collider.vars['acbxh1.l8_from_on_x8h']
    collider.vars['acbxh2.r8_from_on_x8h'] = -collider.vars['acbxh1.l8_from_on_x8h']
    collider.vars['acbxh3.r8_from_on_x8h'] = -collider.vars['acbxh1.l8_from_on_x8h']
    collider.vars['acbxh1.r8_from_on_x8h'] = -collider.vars['acbxh1.l8_from_on_x8h']

    # Enable first mcbx knob (which controls the others)
    assert opt_x8h.vary[8].name == 'acbxh1.l8_from_on_x8h'
    opt_x8h.vary[8].active = True

    # Solve and generate knob
    opt_x8h.solve()
    opt_x8h.generate_knob()

    # ---------- on_x8v ----------

    opt_x8v = collider.match_knob(
        knob_name='on_x8v', knob_value_end=(angle_match_ip8 * 1e6),
        targets=(targets_close_bump + [
            xt.TargetSet(line='lhcb1', at='ip8', y=0, py=angle_match_ip8),
            xt.TargetSet(line='lhcb2', at='ip8', y=0, py=-angle_match_ip8),
        ]),
        vary=[
            xt.VaryList(correctors_ir8_single_beam_v),
            xt.VaryList(correctors_ir8_common_v, tag='mcbx')],
        run=False, init=twinit_zero_orbit, **bump_range_ip8,
    )

    # Set mcbx by hand
    testkqx8=abs(collider.varval['kqx.l8'])*7000./0.3
    acbx_xing_ir8 = 1.0e-6 if testkqx8 > 210. else 11.0e-6 # Value for 170 urad crossing
    # Set MCBX by hand
    for icorr in [1, 2, 3]:
        collider.vars[f'acbxv{icorr}.l8_from_on_x8v'] = acbx_xing_ir8 * angle_match_ip8 / 170e-6
        collider.vars[f'acbxv{icorr}.r8_from_on_x8v'] = -acbx_xing_ir8 * angle_match_ip8 / 170e-6

    # First round of optimization without changing mcbx
    opt_x8v.disable_vary(tag='mcbx')
    opt_x8v.step(3) # perform 3 steps without checking for convergence

    # Solve with all vary active and generate knob
    opt_x8v.enable_vary(tag='mcbx')
    opt_x8v.solve()
    opt_x8v.generate_knob()

    v = collider.vars
    f = collider.functions
    v['phi_ir8'] = 0.
    for irn in [8]:
        v[f'cphi_ir{irn}'] = f.cos(v[f'phi_ir{irn}'] * np.pi / 180.)
        v[f'sphi_ir{irn}'] = f.sin(v[f'phi_ir{irn}'] * np.pi / 180.)
        v[f'on_x{irn}h']   =  v[f'on_x{irn}'] * v[f'cphi_ir{irn}']
        v[f'on_x{irn}v']   =  v[f'on_x{irn}'] * v[f'sphi_ir{irn}']
        v[f'on_sep{irn}h'] = -v[f'on_sep{irn}'] * v[f'sphi_ir{irn}']
        v[f'on_sep{irn}v'] =  v[f'on_sep{irn}'] * v[f'cphi_ir{irn}']
        v[f'on_o{irn}h']   =  v[f'on_o{irn}'] * v[f'cphi_ir{irn}']
        v[f'on_o{irn}v']   =  v[f'on_o{irn}'] * v[f'sphi_ir{irn}']
        v[f'on_a{irn}h']   = -v[f'on_a{irn}'] * v[f'sphi_ir{irn}']
        v[f'on_a{irn}v']   =  v[f'on_a{irn}'] * v[f'cphi_ir{irn}']

    opt = {
        'on_x8h': opt_x8h, 'on_x8v': opt_x8v
    }
    return opt

# %%
# mtcknbip8 = opt50m.ir8.match_knobs(knob_name='on_x8h')

# %%
# collider['b1'].vars[]

# collider.elements[0]

# %%
_aux = match_xing_ip8(collider)

# %% [markdown]
# ## Create collision optics

# %%
vdmopt_50m = LHCOptics.from_json("data/opt_2025_50m.json")
# vdmopt_50m.set_xsuite_model("data/lhc.json")
vdmopt_50m.set_xsuite_model("acc-models-lhc/xsuite/lhc.json")

twb1, twb2 = vdmopt_50m.twiss()
vdmopt_50m

# %%
vdmopt_50m.ir8.knobs

# %%
vdmopt_50m.ir8.plot()

# %%
vdmopt_50m.check()

# %%
vdmopt_50m.ir8.knobs

# %%
vdmopt_50m.ir8.plot(yl='x y')

# %%
vdmopt_50m.model['on_x8h'] = -300
vdmopt_50m.ir8.plot(yl='x y')

# %%
vdmopt_50m.update()
vdmopt_50m.ir8.knobs

# %%
vdmopt_50m.set_circuits("data/lhccircuits.json")
vdmopt_50m.circuits

# %%
vdmopt_50m.ir8.strengths

# %%
for k,v in vdmopt_50m.ir8.strengths.items():
    _cir = vdmopt_50m.circuits.madname[k]
    if v != 0:
        _ic = _cir.get_current(abs(v))
    else:
        _ic = 0
    print(k,v, _ic)
    assert _cir.imin < _cir.get_current(v) < _cir.imax, f'Out of range {k=}, {v=}, {_ic=} {_cir.imin=}, {_cir.imax=}'

# %%
cir=vdmopt_50m.circuits.madname["acbyhs5.r8b1"]
print(cir.get_current(vdmopt_50m.ir8.strengths['acbyhs5.r8b1']))

# %%
cir=vdmopt_50m.circuits.madname["acbxh1.l8"]
print(cir.get_current(vdmopt_50m.ir8.strengths['acbxh1.l8']))

# %%
vdmopt_50m.model['on_x8h'] = -300
vdmopt_50m.update()
vdmopt_50m.ir8.update_strengths()

# %%
vdmopt_50m.ir8.knobs

# %%
vdmopt_50m.ir8.strengths

# %%
# 'RCBYHS5.R8B'

# %%
cir.imax

# %% [markdown]
# ## - Create optics from MAD-X file

# %%
if 0: 
    from cpymad.madx import Madx

    mymad = Madx()

    mymad.input(f'''
        call, file="acc-models-lhc/lhc.seq";

        beam, sequence=lhcb1, bv= 1, particle=proton, charge=1, mass=0.938272046,
        pc= 450.0,   npart=1.2e11,kbunch=2556, ex=5.2126224777777785e-09,ey=5.2126224777777785e-09;
        beam, sequence=lhcb2, bv=-1, particle=proton, charge=1, mass=0.938272046,
        pc= 450.0,   npart=1.2e11,kbunch=2556, ex=5.2126224777777785e-09,ey=5.2126224777777785e-09;

        call,file="/afs/cern.ch/work/e/efthymio/public/vdm_optics/vdm2025/opticsfile_2025.11";

        on_x8h := -300;
        call,file="acc-models-lhc/aperture/aperture.b1.madx";
        call,file="acc-models-lhc/aperture/aperture.b2.madx";
        call,file="acc-models-lhc/aperture/aper_tol.b1.madx";
        call,file="acc-models-lhc/aperture/aper_tol.b2.madx";
        use,sequence=lhcb1;
        use,sequence=lhcb2;
        ''')

    mymad.twiss()
    vdmopt_50m = LHCOptics.from_madx(mymad)

# %%
vdmopt_50m.ir8.plot()

# %%
vdmopt_50m.ir8.match_knobs??

# %%
def match_xing_ip8(collider):
    
    all_knobs_ip8 = [
            'acbxh1.l8', 'acbxh2.l8', 'acbxh3.l8',
            'acbxv1.l8', 'acbxv2.l8', 'acbxv3.l8', 
            
            'acbxh1.r8', 'acbxh2.r8', 'acbxh3.r8', 
            'acbxv1.r8', 'acbxv2.r8', 'acbxv3.r8',

            'acbyhs4.l8b1', 'acbyhs4.l8b2',
            'acbyvs4.l8b1', 'acbyvs4.l8b2', 
       
            'acbyhs4.r8b1'  'acbyhs4.r8b2',
            'acbyvs4.r8b1', 'acbyvs4.r8b2',
                  
            'acbchs5.l8b1', 'acbchs5.l8b2',
            'acbcvs5.l8b1', 'acbcvs5.l8b2',
                       
            'acbyhs5.r8b1', 'acbyhs5.r8b2', 
            'acbyvs5.r8b1', 'acbyvs5.r8b2', 
             
            'xip8b1', 'yip8b1', 'pxip8b1', 'pyip8b1',
            'xip8b2', 'yip8b2', 'pxip8b2', 'pyip8b2',
        ]


    # kill all existing knobs
    for kk in all_knobs_ip8:
        collider.vars[kk] = 0

    twinit_zero_orbit = [xt.TwissInit(), xt.TwissInit()]

    targets_close_bump = [
        xt.TargetSet(line='lhcb1', at=xt.END, x=0, px=0, y=0, py=0),
        xt.TargetSet(line='lhcb2', at=xt.END, x=0, px=0, y=0, py=0),
    ]

    bump_range_ip8 = {
        'start': ['s.ds.l8.b1', 's.ds.l8.b2'],
        'end': ['e.ds.r8.b1', 'e.ds.r8.b2'],
    }

    correctors_ir8_single_beam_h = [
        'acbyhs4.l8b1', 'acbyhs4.r8b2', 'acbyhs4.l8b2', 'acbyhs4.r8b1',
        'acbchs5.l8b2', 'acbchs5.l8b1', 'acbyhs5.r8b1', 'acbyhs5.r8b2']

    correctors_ir8_single_beam_v = [
        'acbyvs4.l8b1', 'acbyvs4.r8b2', 'acbyvs4.l8b2', 'acbyvs4.r8b1',
        'acbcvs5.l8b2', 'acbcvs5.l8b1', 'acbyvs5.r8b1', 'acbyvs5.r8b2']

    correctors_ir8_common_h = [
        'acbxh1.l8', 'acbxh2.l8', 'acbxh3.l8', 'acbxh1.r8', 'acbxh2.r8', 'acbxh3.r8']

    correctors_ir8_common_v = [
        'acbxv1.l8', 'acbxv2.l8', 'acbxv3.l8', 'acbxv1.r8', 'acbxv2.r8', 'acbxv3.r8']

    #########################
    # Match IP offset knobs #
    #########################

    offset_match = 0.5e-3

    # ---------- on_o8v ----------

    opt_o8v = collider.match_knob(
        knob_name='on_o8v', knob_value_end=(offset_match * 1e3),
        targets=(targets_close_bump + [
            xt.TargetSet(line='lhcb1', at='ip8', y=offset_match, py=0),
            xt.TargetSet(line='lhcb2', at='ip8', y=offset_match, py=0),
        ]),
        vary=xt.VaryList(correctors_ir8_single_beam_v),
        run=False, init=twinit_zero_orbit, **bump_range_ip8,
    )
    opt_o8v.solve()
    opt_o8v.generate_knob()

    # ---------- on_o8h ----------

    opt_o8h = collider.match_knob(
        knob_name='on_o8h', knob_value_end=(offset_match * 1e3),
        targets=(targets_close_bump + [
            xt.TargetSet(line='lhcb1', at='ip8', x=offset_match, px=0),
            xt.TargetSet(line='lhcb2', at='ip8', x=offset_match, px=0),
        ]),
        vary=xt.VaryList(correctors_ir8_single_beam_h),
        run=False, init=twinit_zero_orbit, **bump_range_ip8,
    )
    opt_o8h.solve()
    opt_o8h.generate_knob()

    ##############################
    # Match angular offset knobs #
    ##############################

    ang_offset_match = 30e-6

    # ---------- on_a8h ----------

    opt_a8h = collider.match_knob(
        knob_name='on_a8h', knob_value_end=(ang_offset_match * 1e6),
        targets=(targets_close_bump + [
            xt.TargetSet(line='lhcb1', at='ip8', x=0, px=ang_offset_match),
            xt.TargetSet(line='lhcb2', at='ip8', x=0, px=ang_offset_match),
        ]),
        vary=xt.VaryList(correctors_ir8_single_beam_h),
        run=False, init=twinit_zero_orbit, **bump_range_ip8,
    )

    opt_a8h.solve()
    opt_a8h.generate_knob()

    # ---------- on_a8v ----------

    opt_a8v = collider.match_knob(
        knob_name='on_a8v', knob_value_end=(ang_offset_match * 1e6),
        targets=(targets_close_bump + [
            xt.TargetSet(line='lhcb1', at='ip8', y=0, py=ang_offset_match),
            xt.TargetSet(line='lhcb2', at='ip8', y=0, py=ang_offset_match),
        ]),
        vary=xt.VaryList(correctors_ir8_single_beam_v),
        run=False, init=twinit_zero_orbit, **bump_range_ip8,
    )

    opt_a8v.solve()
    opt_a8v.generate_knob()

    ##############################
    # Match crossing angle knobs #
    ##############################

    angle_match_ip8 = 170e-6

    # ---------- on_x8h ----------

    opt_x8h = collider.match_knob(
        knob_name='on_x8h', knob_value_end=(angle_match_ip8 * 1e6),
        targets=(targets_close_bump + [
            xt.TargetSet(line='lhcb1', at='ip8',  x=0, px=angle_match_ip8),
            xt.TargetSet(line='lhcb2', at='ip8',  x=0, px=-angle_match_ip8),
        ]),
        vary=[
            xt.VaryList(correctors_ir8_single_beam_h),
            xt.VaryList(correctors_ir8_common_h, tag='mcbx')],
        run=False, init=twinit_zero_orbit, **bump_range_ip8,
    )

    # Set mcbx by hand (reduce value by 10, to test matching algorithm)
    testkqx8=abs(collider.varval['kqx.l8'])*7000./0.3
    acbx_xing_ir8 = 1.0e-6 if testkqx8 > 210. else 11.0e-6 # Value for 170 urad crossing

    # Set mcbx by hand
    for icorr in [1, 2, 3]:
        collider.vars[f'acbxh{icorr}.l8_from_on_x8h'] = acbx_xing_ir8 * angle_match_ip8 / 170e-6
        collider.vars[f'acbxh{icorr}.r8_from_on_x8h'] = -acbx_xing_ir8 * angle_match_ip8 / 170e-6

    #   (reduce value by 10, to test matching algorithm)
    #   collider.vars[f'acbxh{icorr}.l8_from_on_x8h'] = acbx_xing_ir8 * angle_match_ip8 / 170e-6 * 0.1
    #   collider.vars[f'acbxh{icorr}.r8_from_on_x8h'] = -acbx_xing_ir8 * angle_match_ip8 / 170e-6 * 0.1

    # First round of optimization without changing mcbx
    opt_x8h.disable_vary(tag='mcbx')
    opt_x8h.step(3) # perform 3 steps without checking for convergence

    # Link all mcbx strengths to the first one
    collider.vars['acbxh2.l8_from_on_x8h'] =  collider.vars['acbxh1.l8_from_on_x8h']
    collider.vars['acbxh3.l8_from_on_x8h'] =  collider.vars['acbxh1.l8_from_on_x8h']
    collider.vars['acbxh2.r8_from_on_x8h'] = -collider.vars['acbxh1.l8_from_on_x8h']
    collider.vars['acbxh3.r8_from_on_x8h'] = -collider.vars['acbxh1.l8_from_on_x8h']
    collider.vars['acbxh1.r8_from_on_x8h'] = -collider.vars['acbxh1.l8_from_on_x8h']

    # Enable first mcbx knob (which controls the others)
    assert opt_x8h.vary[8].name == 'acbxh1.l8_from_on_x8h'
    opt_x8h.vary[8].active = True

    # Solve and generate knob
    opt_x8h.solve()
    opt_x8h.generate_knob()

    # ---------- on_x8v ----------

    opt_x8v = collider.match_knob(
        knob_name='on_x8v', knob_value_end=(angle_match_ip8 * 1e6),
        targets=(targets_close_bump + [
            xt.TargetSet(line='lhcb1', at='ip8', y=0, py=angle_match_ip8),
            xt.TargetSet(line='lhcb2', at='ip8', y=0, py=-angle_match_ip8),
        ]),
        vary=[
            xt.VaryList(correctors_ir8_single_beam_v),
            xt.VaryList(correctors_ir8_common_v, tag='mcbx')],
        run=False, init=twinit_zero_orbit, **bump_range_ip8,
    )

    # Set mcbx by hand
    testkqx8=abs(collider.varval['kqx.l8'])*7000./0.3
    acbx_xing_ir8 = 1.0e-6 if testkqx8 > 210. else 11.0e-6 # Value for 170 urad crossing
    # Set MCBX by hand
    for icorr in [1, 2, 3]:
        collider.vars[f'acbxv{icorr}.l8_from_on_x8v'] = acbx_xing_ir8 * angle_match_ip8 / 170e-6
        collider.vars[f'acbxv{icorr}.r8_from_on_x8v'] = -acbx_xing_ir8 * angle_match_ip8 / 170e-6

    # First round of optimization without changing mcbx
    opt_x8v.disable_vary(tag='mcbx')
    opt_x8v.step(3) # perform 3 steps without checking for convergence

    # Solve with all vary active and generate knob
    opt_x8v.enable_vary(tag='mcbx')
    opt_x8v.solve()
    opt_x8v.generate_knob()

    ##########################
    # Match separation knobs #
    ##########################

    sep_match = 2e-3

    # ---------- on_sep8h ----------

    opt_sep8h = collider.match_knob(
        knob_name='on_sep8h', knob_value_end=(sep_match * 1e3),
        targets=(targets_close_bump + [
            xt.TargetSet(line='lhcb1', at='ip8',  x=sep_match, px=0),
            xt.TargetSet(line='lhcb2', at='ip8',  x=-sep_match, px=0),
        ]),
        vary=[
            xt.VaryList(correctors_ir8_single_beam_h),
            xt.VaryList(correctors_ir8_common_h, tag='mcbx')],
        run=False, init=twinit_zero_orbit, **bump_range_ip8,
    )

    # Set mcbx by hand
    testkqx8=abs(collider.varval['kqx.l8'])*7000./0.3
    acbx_sep_ir8 = 18e-6 if testkqx8 > 210. else 16e-6

    for icorr in [1, 2, 3]:
        collider.vars[f'acbxh{icorr}.l8_from_on_sep8h'] = acbx_sep_ir8 * sep_match / 2e-3
        collider.vars[f'acbxh{icorr}.r8_from_on_sep8h'] = acbx_sep_ir8 * sep_match / 2e-3

    # Match other correctors with fixed mcbx and generate knob
    opt_sep8h.disable_vary(tag='mcbx')
    opt_sep8h.solve()
    opt_sep8h.generate_knob()

    # ---------- on_sep8v ----------

    opt_sep8v = collider.match_knob(
        knob_name='on_sep8v', knob_value_end=(sep_match * 1e3),
        targets=(targets_close_bump + [
            xt.TargetSet(line='lhcb1', at='ip8',  y=sep_match, py=0),
            xt.TargetSet(line='lhcb2', at='ip8',  y=-sep_match, py=0),
        ]),
        vary=[
            xt.VaryList(correctors_ir8_single_beam_v),
            xt.VaryList(correctors_ir8_common_v, tag='mcbx')],
        run=False, init=twinit_zero_orbit, **bump_range_ip8,
    )

    # Set mcbx by hand
    testkqx8=abs(collider.varval['kqx.l8'])*7000./0.3
    acbx_sep_ir8 = 18e-6 if testkqx8 > 210. else 16e-6

    for icorr in [1, 2, 3]:
        collider.vars[f'acbxv{icorr}.l8_from_on_sep8v'] = acbx_sep_ir8 * sep_match / 2e-3
        collider.vars[f'acbxv{icorr}.r8_from_on_sep8v'] = acbx_sep_ir8 * sep_match / 2e-3

    # Match other correctors with fixed mcbx and generate knob
    opt_sep8v.disable_vary(tag='mcbx')
    opt_sep8v.solve()
    opt_sep8v.generate_knob()

    v = collider.vars
    f = collider.functions
    v['phi_ir8'] = 0.
    for irn in [8]:
        v[f'cphi_ir{irn}'] = f.cos(v[f'phi_ir{irn}'] * np.pi / 180.)
        v[f'sphi_ir{irn}'] = f.sin(v[f'phi_ir{irn}'] * np.pi / 180.)
        v[f'on_x{irn}h']   =  v[f'on_x{irn}'] * v[f'cphi_ir{irn}']
        v[f'on_x{irn}v']   =  v[f'on_x{irn}'] * v[f'sphi_ir{irn}']
        v[f'on_sep{irn}h'] = -v[f'on_sep{irn}'] * v[f'sphi_ir{irn}']
        v[f'on_sep{irn}v'] =  v[f'on_sep{irn}'] * v[f'cphi_ir{irn}']
        v[f'on_o{irn}h']   =  v[f'on_o{irn}'] * v[f'cphi_ir{irn}']
        v[f'on_o{irn}v']   =  v[f'on_o{irn}'] * v[f'sphi_ir{irn}']
        v[f'on_a{irn}h']   = -v[f'on_a{irn}'] * v[f'sphi_ir{irn}']
        v[f'on_a{irn}v']   =  v[f'on_a{irn}'] * v[f'cphi_ir{irn}']

    opt = {
        'on_o8h': opt_o8h, 'on_o8v': opt_o8v,
        'on_a8h': opt_a8h, 'on_a8v': opt_a8v,
        'on_x8h': opt_x8h, 'on_x8v': opt_x8v,
        'on_sep8h': opt_sep8h, 'on_sep8v': opt_sep8v,
    }
    return opt
